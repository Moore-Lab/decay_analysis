# %%
import matplotlib.pyplot as plt
import numpy as np
import importlib
import bead_utils as bu

# %%
importlib.reload(bu)

noise = 30
## equal noise
noise_vals = [40, 90, 200] 

exp_bins, epdf_ndof = bu.calc_expected_spectrum(noise_vals, docut=True, make_plots=True)

#ndof = [1,2,3]
#plt.figure()
#for n,epdf in zip(ndof, epdf_ndof):
#    plt.plot(exp_bins, epdf, label="DOF = %d"%n)

#plt.xlabel("Reconstructed momentum [MeV]")
#plt.ylabel("Probability density [MeV$^{-1}$]")
#plt.xlim(0,500)
#plt.legend()
