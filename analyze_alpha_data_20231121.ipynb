# %%
import numpy as np
import matplotlib.pyplot as plt
from natsort import natsorted
import bead_utils as bu
import os, glob, re, importlib, numbers, pickle
import scipy.optimize as opt
import scipy.signal as sig
from matplotlib.backends.backend_pdf import PdfPages
from scipy.ndimage import gaussian_filter1d

# %%
base_path = "/Volumes/DATA/"
sphere_data = ["20231121/1/meas/1",
               "20231121/1/meas/2",
               "20231121/1/meas/3"]

calib_data = ["20231121/1/calibration/1", "20231121/1/calibration/2",]
calib_noise_path = ["20231030/2/calibration/1/noise",
                    "20231030/2/calibration/2/noise",]

file_label= '20231121'
code_path = "/Users/dcmoore/Library/CloudStorage/GoogleDrive-david.c.moore@yale.edu/My Drive/yale/uspheres/decay_analysis"
plots_dir = os.path.join(code_path, "plots", file_label)
if(not os.path.isdir(plots_dir)):
    os.makedirs(plots_dir)
data_dir = os.path.join(code_path, "data", file_label)
if(not os.path.isdir(data_dir)):
    os.makedirs(data_dir)

# %%
## make a list of all the calibration files and sort by impulse size
data_list = []
for curr_path in sphere_data:
    curr_file_list = natsorted(glob.glob(os.path.join(base_path, curr_path, "*.h5")))
    for file in curr_file_list:
        data_list.append(file)

# %%
## process data to find charge correlation
importlib.reload(bu)

remake_files = False

num_pts_per_charge_recon = 2**16 ## points to use in each fft segment for charge reconstruction

if(remake_files):
    charge_vec = []
    corr_vec = []
    filament_vec = []
    lamp_vec = []
    for i,f in enumerate(data_list):

        if(i%10 == 0): print("working on file %d: %s"%(i, f))
        
        cdat, attr, fhandle = bu.get_data(f)
        if(not fhandle):
            continue    

        fname = "corr_%d.png"%i
        #corr_val, curr_corr_vec = bu.simple_correlation_with_drive(cdat, attr, drive_freq, bw=1, decstages=50)
        curr_corr_vec = bu.signed_correlation_with_drive(cdat, attr, nperseg=num_pts_per_charge_recon)
        if(i == 0):
            corr_vec = 1.0*curr_corr_vec
        else:
            corr_vec = np.vstack((corr_vec, curr_corr_vec))

        corr_val = np.median(curr_corr_vec[:,0])

        time = attr["Time"]
        charge_vec.append([time, corr_val])
    
        ## now times lamp and filament are on
        curr_lamp, curr_fil = bu.get_lamp_and_filament(cdat, num_pts_per_charge_recon)
        
        if(i == 0):
            lamp_vec = 1.0*curr_lamp
            filament_vec = 1.0*curr_fil
        else:
            lamp_vec = np.hstack((lamp_vec, curr_lamp))
            filament_vec = np.hstack((filament_vec, curr_fil))

    charge_vec = np.array(charge_vec)
    np.save(data_dir+"/charge_steps_%s.npy"%file_label, charge_vec)
    np.save(data_dir+"/charge_steps_vec_%s.npy"%file_label, corr_vec)
    np.savez(data_dir+"/lamp_filament_data_%s.npz"%file_label, lamp_vec=lamp_vec, filament_vec=filament_vec)
else:
    charge_vec = np.load(data_dir+"/charge_steps_%s.npy"%file_label)
    corr_vec = np.load(data_dir+"/charge_steps_vec_%s.npy"%file_label)

    lfdat = np.load(data_dir+"/lamp_filament_data_%s.npz"%file_label)
    lamp_vec = lfdat["lamp_vec"]
    filament_vec = lfdat["filament_vec"]

# %%
## correct for possible drift in drive voltage (this appears real since the residual improves)
corr_idx = 2
gpts = corr_vec[:,3] > 70 ## only use points before the drive was high, before Jiaxiang changed it in folder 3
corr_vec[gpts,corr_idx] /= corr_vec[gpts,3]/np.median(corr_vec[gpts,3])

# %%
## Make a list of folder numbers and file names
cdat, attr, fhandle = bu.get_data(data_list[0])
num_pts_per_file = int(len(cdat[:,0])/num_pts_per_charge_recon)
folder_vec = []

for j,f in enumerate(data_list):
    parts = f.split('/')
    folder_vec.append([int(parts[-2])]*num_pts_per_file)
folder_vec = np.ndarray.flatten(np.array(folder_vec))

# %%
## plot the time correlation with the drive
time_hours = (corr_vec[:,-1]-corr_vec[0,-1])/3600

plt.figure(figsize =(6,4))
plt.plot(time_hours, corr_vec[:,3])
plt.xlabel("Time since start [hours]")
plt.ylabel("Drive amplitude (col 8) at 110.93 Hz")
#plt.ylim(165, 175)
ax1 = plt.gca()
ax2 = ax1.twinx()
ax2.plot(time_hours, folder_vec, color='orange')
plt.ylabel("Folder number")
plt.grid(True)
plt.savefig(plots_dir+"/drive_amp_vs_time.png", dpi=300, bbox_inches='tight')

# %%
#import PyQt5
#import matplotlib
#matplotlib.use('Qt5Agg')
#%matplotlib

# %%
## find the calibration constant that minimizes distance from the nearest integer
cal_fac_init = 0.016
cal_fac_err = 0.02

def min_charge_dist(cal, dat):
    cal_dat = dat/cal
    gpts = np.abs(cal_dat) < 10
    cal_dat = cal_dat[gpts]
    return np.sum( (cal_dat - np.round(cal_dat))**2 )/np.sum(gpts) + (cal-cal_fac_init)**2/(2*(cal_fac_err)**2)

## initial plot of the charge steps versus time
n_resamp = 5

charges=corr_vec[1:,corr_idx]/cal_fac_init
filt_vec = gaussian_filter1d(charges,n_resamp)

best_cal = opt.minimize(min_charge_dist, cal_fac_init, args=filt_vec)
print(best_cal.x)
# Out:
# [0.015383]

# %%
cal_fac = 0.0157
corr_idx = 2
xmin, xmax = 0, len(corr_vec)
ymin, ymax = -20, 110
init_charge = np.round(np.median(corr_vec[0:10,corr_idx]/cal_fac))


plt.figure(figsize=(12,8))
plt.subplot(2,1,1)
#plt.plot(corr_vec[1:,1]/cal_fac*recal, '-')
charges=corr_vec[1:,corr_idx]/cal_fac
plt.plot(charges, '-')
n_resamp = 5
filt_vec = gaussian_filter1d(charges,n_resamp)
plt.plot(filt_vec, '-')
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
plt.gca().set_yticks(range(ymin,ymax))
plt.grid(True)

plt.subplot(2,1,2)
dv = np.diff(corr_vec[:,corr_idx]/cal_fac)
#plt.plot(dv)
b,a = sig.butter(3,0.3)
dv2 = sig.filtfilt(b,a,dv)
dv_chopped = np.round(dv)
N=25
dv2 = np.convolve(dv, sig.gaussian(N,N/4), mode='same')
bpts = ((np.abs(dv2) < 5) | (np.abs(dv) < 5)) # | (np.abs(dv) < 0.07*corr_vec[:-1, corr_idx]/cal_fac)
dv_chopped[bpts] = 0
#dv_chopped[dv_chopped > 5] = dv2[dv_chopped > 5]

#plt.plot(dv2)
## fix up missed steps
step_vals = np.loadtxt(data_dir+"/step_locations_%s.txt"%file_label, skiprows=1, delimiter=',')
for i in range(np.shape(step_vals)[0]):
    cvals = step_vals[i,:] 
    sval = np.round(cvals[2]*0.017/cal_fac) ## 0.017 is the initial calibration constant
    if(cvals[1] > 0):
        dv_chopped[int(cvals[0]):int(cvals[1])] = sval
    else:
        dv_chopped[int(cvals[0])] = sval

running_charge = np.cumsum(dv_chopped) + init_charge

## nonlinearity correction
#filt_vec = filt_vec*(1 - 0.0000*filt_vec)
#gpts = np.abs(filt_vec) < 20
#tt = np.arange(len(filt_vec))
#plt.plot(tt[gpts], filt_vec[gpts] - np.round(filt_vec[gpts]), 'k.', ms=1)


plt.plot(running_charge - filt_vec, 'k.', ms=1)
plt.ylim(-2,2)

#plt.subplot(3,1,3)
#plt.plot(dv)
#plt.plot(dv2)
#plt.plot(dv_chopped)
plt.xlim(xmin, xmax)
#plt.ylim(-1,10)
#plt.grid(True)


plt.subplot(2,1,1)
plt.plot(running_charge, '-')
plt.xlim(xmin, xmax)
# Out:
# (0.0, 45888.0)

# %%
importlib.reload(bu)

## make a dead time vector
live_vec = 1.0*time_hours
bad_pts = (time_hours > 80.5) # (folder_vec == 5) | (time_hours > 55)
live_vec = live_vec[~bad_pts]

calib_lamp_list = []
calib_lamp = np.zeros_like(time_hours, dtype=bool)
for cl in calib_lamp_list:
    calib_lamp = calib_lamp | ((time_hours>cl[0]) & (time_hours<cl[1])) ## times when the lamp calibration is on
live_vec_lamp = time_hours[~calib_lamp]

## add buffer on either side:
filament_vec_new = filament_vec > 0
filament_vec_new = filament_vec_new | np.roll(filament_vec_new,-1)
live_vec_filament = time_hours[~(filament_vec_new)]

dead_period_edges = bu.get_edges_from_livetime_vec(live_vec, time_hours, [])
lamp_period_edges = bu.get_edges_from_livetime_vec(live_vec_lamp, time_hours, dead_period_edges)
filament_period_edges = bu.get_edges_from_livetime_vec(live_vec_filament, time_hours, dead_period_edges+lamp_period_edges)

print(filament_period_edges)

tot_dead_periods = 0
dead_periods_to_use = [dead_period_edges, lamp_period_edges, filament_period_edges]
for dpe in dead_periods_to_use:
    for dp in dpe:
        tot_dead_periods += dp[1]-dp[0]


tot_livetime = time_hours[-1] - tot_dead_periods
print(time_hours[-1], tot_dead_periods, tot_livetime)
# Out:
# [[0.4110391714837816, 0.4188251170847151], [0.44067045039600794, 0.44847349802652997], [0.4703188313378228, 0.47813840905825294], [0.49998374236954585, 0.5059701193703545], [0.5296358970801035, 0.5356331457032097], [0.5592989235454136, 0.5670824282699161], [0.588927761581209, 0.5949277546670702], [0.6185935323768191, 0.6245658058590359], [0.6482315837012397, 0.6560490473111471], [0.6778943806224399, 0.6856648853090075], [0.7075102186203003, 0.7134651146994697], [0.7371308924092187, 0.7431385962168375], [0.7668043739265866, 0.7746552651458316], [0.7965005984571245, 0.802485933303833], [0.826151711013582, 0.8321262590090434], [0.8557920368512472, 0.8636209207110935], [0.8854662540223863, 0.8914192607667711], [0.9150850386089748, 0.9210839549700419], [0.9447497328122457, 0.9526054864459568], [0.954425930844413, 0.961707708703147], [0.9762712642881606, 0.98222773220804], [1.0040730655193328, 1.0119831751452553], [1.0265467307302687, 1.033828508456548], [1.033828508456548, 1.0398740238613553], [1.0635398015711042, 1.0695693103472392], [1.260487651957406, 1.2677694296836852], [1.2714103186130523, 1.2793299520015717], [1.2793299520015717, 1.2847912853293948], [1.5981855132844713, 1.606041547060013], [1.6278868803713056, 1.633935464753045], [1.6576012425952487, 1.6635467492209541], [1.6872125270631577, 1.6950242722034454], [1.7168696055147383, 1.7246747359964583], [1.7465200693077512, 1.7525123355123733], [1.7761781133545769, 1.7822707835833231], [1.8059365612930722, 1.8138215390841166], [1.8356668723954095, 1.841645818816291], [2.1327474888165794, 2.140602075126436], [2.1624474084377288, 2.1685251837306554], [2.192190961572859, 2.1981601585282218], [4.181366560856501, 4.189200310177273], [4.211045643488566, 4.218947647545073], [4.240792980856366, 4.248614423804813], [4.270459757116106, 4.276526887681749], [4.300192665523953, 4.3062278119723], [4.329893589682049, 4.33770365913709], [4.359548992448383, 4.365596772299872], [4.389262550142076, 4.395288384225633], [4.715880274640189, 4.7237460511260565], [4.745591384437349, 4.751682711972131], [7.061181919044919, 7.069041815598806], [7.090887148910099, 7.096882806089189], [7.120548583931393, 7.126570827696058], [8.249242221911748, 8.255240677727594], [8.278906455569796, 8.284933202531603], [8.308598980373807, 8.31458095550537], [8.338246733347574, 8.344297156863743], [8.367962934573491, 8.375794715351528], [8.397640048662822, 8.403681369622548], [8.427347147464753, 8.433348233699798], [8.457014011542002, 8.463028681543138], [8.486694459252888, 8.49454297039244], [10.833627365297742, 10.839622151321835], [10.863287929031584, 10.869314555592007], [10.892980333301756, 10.89901137722863], [10.922677155070835, 10.93053008503384], [10.952375418345133, 10.960248095724317], [10.982093429035611, 10.989926985369788], [11.01177231868108, 11.017768417464362], [11.041434195306566, 11.047413411405351], [16.206869984202914, 16.214650916258496], [16.238316694100696, 16.244307130442724], [16.26615246375402, 16.274012149704827], [16.29585748301612, 16.3036495841874], [16.325494917498695, 16.33332510802481], [16.355170441336103, 16.3611646800571], [16.38483045776685, 16.390793029997084], [21.020332557492786, 21.028153578705258], [21.04999891201655, 21.05786589582761], [21.08153167353736, 21.08750479247835], [21.109350125789643, 21.115368264516196], [21.1390340423584, 21.14684431393941], [30.153669052653843, 30.161503740814], [30.18334907412529, 30.191174550453823], [30.213019883765114, 30.218999336295656], [30.24266511413786, 30.248629459540048], [30.2722952372498, 30.27829231156243], [34.484681702189974, 34.4924969013532], [34.51434223466449, 34.52216174814436], [34.54400708145565, 34.55185450845295], [34.57369984176424, 34.579660812748806], [34.60332659059101, 34.60928587754567], [42.3226787132687, 42.330504430267546], [42.352349763578836, 42.35835956917869], [87.30074068519804, 87.30074068519804]]
# 87.30074068519804 9.645241145160456 77.65549954003758

# %%
## define plotting function for dead times
def fill_dps(dead_period_edges, color='blue', lab="Dead time"):
    yy = plt.ylim()
    for i,dp in enumerate(dead_period_edges):
        if(i==0 and len(lab)>0):
            plt.fill_between(dp, [yy[0],yy[0]], [yy[1],yy[1]], color=color, alpha=0.2, label=lab)
        else:
            plt.fill_between(dp, [yy[0],yy[0]], [yy[1],yy[1]], color=color, alpha=0.2)  
    plt.ylim(yy)

# %%
## now make some cleaned up versions of the charge step plots versus time
plt.figure(figsize=(14,4))
#plt.subplot(2,1,1)
#plt.plot(corr_vec[1:,1]/cal_fac*recal, '-')
t12 = 10.6
xv1, xv2 = 0, time_hours[-1]
time_vals = time_hours[1:]
plt.plot(time_vals, corr_vec[1:,corr_idx]/cal_fac, 'k-', label="Correlation")
plt.plot(time_vals, running_charge, '-', color='orange', label="Recon. charge")
plt.grid(True)
fill_dps(dead_period_edges)
#fill_dps(lamp_period_edges, 'purple', lab="UV lamp")
fill_dps(filament_period_edges, 'red', lab="Filament")
plt.xlabel("Time since start [hours]")
plt.ylabel("Net charge [$e$]")
plt.legend(loc="upper right")
#plt.ylim(-150,100)
#plt.gca().set_xscale('log')
plt.xlim(xv1, xv2)

#plt.subplot(2,1,2)
#plt.semilogy(time_vals, np.abs(corr_vec[1:,corr_idx]/cal_fac*recal), 'k-', label="Correlation")
#plt.plot(time_vals, np.abs(running_charge), '-', color='orange', label="Recon. charge")
#plt.grid(True)
#plt.ylim(0.5,250)
#fill_dps(dead_period_edges)
#plt.gca().set_xscale('log')
#plt.xlim(xv1, xv2)
#plt.ylabel("Abs(Net charge) [$e$]")
#plt.xlabel("Time since start [hours]")

plt.savefig(plots_dir+"/recon_charge_vs_time_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
## find the locations of the charge changes
all_bad_periods = dead_period_edges + lamp_period_edges + filament_period_edges
bad_pts = np.zeros_like(time_hours[:-1], dtype=bool)
for dp in all_bad_periods:
    bad_pts = bad_pts | ((time_hours[:-1] >= dp[0]) & (time_hours[:-1] <= dp[1]))

min_change = -10
changes = (np.abs(dv_chopped) > 0) & (dv_chopped > min_change) & ~bad_pts
big_changes = (np.abs(dv_chopped) >= 8) & (dv_chopped > min_change) & ~bad_pts


## group consecutive changes
idx_of_charge_changes = np.where(changes)[0]
dup_changes = np.diff(idx_of_charge_changes) <= 2
good_change_list = [ [time_hours[idx_of_charge_changes[0]], dv_chopped[idx_of_charge_changes[0]], running_charge[idx_of_charge_changes[0]-1]] ] 
for j in range(1,len(idx_of_charge_changes)):
    is_dup = dup_changes[j-1]
    if(is_dup):
        good_change_list[-1][1] += dv_chopped[idx_of_charge_changes[j]]
        continue
    good_change_list.append([time_hours[idx_of_charge_changes[j]], dv_chopped[idx_of_charge_changes[j]], running_charge[idx_of_charge_changes[j]-1]])

good_change_list = np.array(good_change_list)

# %%
## we have some negative going ones that are near a filament (but just missed)
## go back and cut these out
filament_buff = 1/60 ## 1 min in hours

for i in range(len(good_change_list)):
    for fpe in filament_period_edges:
        if(good_change_list[i,0] > fpe[0]-filament_buff and good_change_list[i,0] < fpe[1]+filament_buff):
            if(good_change_list[i,1] < 0 or good_change_list[i,1] == 1):
                good_change_list[i,1] = 0
            break

bad_pts = good_change_list[:,1] == 0
good_change_list = good_change_list[~bad_pts,:]

# %%
print(good_change_list)
# Out:
# [[  0.25536694   4.           2.        ]
#  [  0.40193695  88.           6.        ]
#  [  0.5967482   10.          99.        ]
#  [  1.13981219   6.          83.        ]
#  [  1.25320587   6.          89.        ]
#  [  1.32541957  24.         -16.        ]
#  [  1.58362196  40.           8.        ]
#  [  1.81564198   9.          23.        ]
#  [  1.9176001    1.          26.        ]
#  [  2.11636349  18.          27.        ]
#  [  2.70843801   1.           2.        ]
#  [  2.77876623   1.           3.        ]
#  [  3.19460717   6.           4.        ]
#  [  3.21701969   3.          10.        ]
#  [  3.71061465   9.          13.        ]
#  [  4.16862345  30.          22.        ]
#  [  4.50806228  22.           2.        ]
#  [  4.67348994  11.          24.        ]
#  [  5.72166642  18.           2.        ]
#  [  7.04479792  19.          20.        ]
#  [  7.97461034  31.          -3.        ]
#  [  8.04315526   1.          28.        ]
#  [  8.21955456  45.          29.        ]
#  [  9.20396197   2.           0.        ]
#  [  9.26516157  11.           2.        ]
#  [ 10.54279614   1.          13.        ]
#  [ 10.79301426  30.          14.        ]
#  [ 11.42533425  12.          -4.        ]
#  [ 11.69639557   2.           8.        ]
#  [ 13.71299004  16.          10.        ]
#  [ 14.40204614   1.          26.        ]
#  [ 16.20140865  39.          27.        ]
#  [ 19.78876597   2.          -5.        ]
#  [ 20.91862255  17.          -3.        ]
#  [ 20.98886841  35.          14.        ]
#  [ 29.08775818   1.           1.        ]
#  [ 30.13364416  36.           2.        ]
#  [ 33.65561225  11.          -1.        ]
#  [ 34.46647726  35.          10.        ]
#  [ 41.84973899   7.          -5.        ]
#  [ 42.28579179  35.           2.        ]
#  [ 49.78608368   5.           0.        ]
#  [ 51.44425506   2.           5.        ]
#  [ 76.74460944  -1.           1.        ]]

# %%
#save the step locations
np.savez(data_dir+"/charge_data_%s.npz"%file_label, time_hours=time_hours, corr_vec=corr_vec, dv_chopped=dv_chopped, running_charge=running_charge, 
         dead_period_edges=dead_period_edges, lamp_period_edges=lamp_period_edges, filament_period_edges=filament_period_edges,cal_fac=cal_fac,corr_idx=corr_idx,
         good_change_list=good_change_list, tot_livetime=tot_livetime, all_bad_periods=all_bad_periods)

# %%
## plot charge changes vs time
fig, (scatter_ax, hist_ax) = plt.subplots(1, 2, figsize=(14, 4), width_ratios=[3,1])

plt.sca(scatter_ax)
#scatter_ax.plot(time_hours[1:][changes], dv_chopped[changes], 'ro', label='Total counts=%d'%np.sum(changes))
scatter_ax.plot(good_change_list[:,0], good_change_list[:,1], 'ko', label='Total counts=%d'%len(good_change_list[:,1]))
ymin, ymax = -5, 1.1*np.max(good_change_list[:,1])
plt.ylim(ymin,ymax)
fill_dps(dead_period_edges)
fill_dps(lamp_period_edges, 'black', lab="UV lamp")
fill_dps(filament_period_edges, 'red', lab="Filament")
plt.grid(True)
plt.xlim(0, time_hours[-1])
plt.ylabel("Charge change [$e$]")
plt.xlabel("Time since start [hours]")
plt.legend()
#plt.ylim(-2,2)

hh, be = np.histogram(good_change_list[:,1], bins=25, range=(ymin,ymax))
bc = be[:-1] + np.diff(be)/2
#plt.step(be[:-1], hh, where='post', color='k')
plt.sca(hist_ax)
hist_ax.errorbar(hh, bc, xerr=np.sqrt(hh), fmt='ko')
plt.yticks([])
plt.ylim(ymin,ymax)
plt.xlabel("Counts")
plt.subplots_adjust(wspace=0)

plt.savefig(plots_dir+"/charge_changes_vs_time_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(8,6))
plt.plot(good_change_list[:,2], good_change_list[:,1], 'ko')
plt.xlabel("Net charge [$e$]")
plt.ylabel("Charge change [$e$]")
plt.grid(True)
plt.savefig(plots_dir+"/charge_changes_vs_charge_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
def lfun(t, N0, t12, tot_time=tot_livetime, use_norm=True, dead_period_edges=all_bad_periods):
    tint = np.linspace(0, tot_time, 1000)
    norm = np.trapz(0.5**(tint/t12), tint)
    if(use_norm):
        val = 1/norm * 0.5**(t/t12)
    else:
        val = N0 * 0.5**(t/t12)
    bad_pts = np.zeros_like(t)
    for dp in dead_period_edges:
        inrange = ((t > dp[0]) & (t < dp[1]))
        bad_pts = np.logical_or(bad_pts, inrange)
    val[bad_pts] = 0
    return val

def nll(t, N0, t12, tot_time=tot_livetime):
    N = len(t)
    mu = N0*(1 - 0.5**(tot_time/t12))
    poiss = N*np.log(mu) - mu
    return -np.sum(np.log(lfun(t, 1, t12))) - poiss

# %%
t = np.linspace(0, time_hours[-1], 5000)
plt.figure(figsize=(8,6))
plt.plot(t, lfun(t, 1, 10.6))
plt.plot(t, lfun(t, 1, 20))
plt.plot(t, lfun(t, 1, 40))
print(np.trapz(lfun(t, 1, 10.6)),np.trapz(lfun(t, 1, 20)))
# Out:
# 55.48417587116802 55.87812729862061

# %%
## time of decays/half life
decay_times = good_change_list[:,0] #time_hours[1:][changes]
#big_decay_times = time_hours[1:][big_changes]

## likelihood fit
N0_vec = np.linspace(0, 100, 200)
t12_vec = np.linspace(0.5, 30, 200)
nll_mat_all = np.zeros((len(N0_vec), len(t12_vec)))
#nll_mat_big = np.zeros((len(N0_vec), len(t12_vec)))

for i,N0 in enumerate(N0_vec):
    for j,t12 in enumerate(t12_vec):
        nll_mat_all[i,j] = nll(decay_times, N0, t12)
        #nll_mat_big[i,j] = nll(big_decay_times, N0, t12)

nll_mat_all -= np.min(nll_mat_all)
#nll_mat_big -= np.min(nll_mat_big)
# Out:
# /var/folders/sz/h29lm_2j53v8vmw0zm_6hxqm0000gn/T/ipykernel_21534/412691564.py:18: RuntimeWarning: divide by zero encountered in log
#   poiss = N*np.log(mu) - mu

# %%
t12_true = 10.6 ## https://www.nndc.bnl.gov/nudat3/DecayRadiationServlet?nuc=212Pb&unc=NDS

nlls = [nll_mat_all,] # nll_mat_big]
labs = ["Fit to all reconstructed decays", "Fit to decays $>6$ $e$"]

fig2d = plt.figure(figsize=(14,5))
params_from_profile = []
for j in range(1):

    profile = np.zeros_like(t12_vec)
    profile_nll = np.zeros_like(t12_vec)
    for k in range(len(t12_vec)):
        profile[k] = N0_vec[np.argmin(nlls[j][:,k])]
        profile_nll[k] = 2*np.min(nlls[j][:,k])

    plt.figure(fig2d.number)
    plt.subplot(1,2,j+2)
    cup = np.where((profile_nll <= 1) & (np.roll(profile_nll,-1) > 1))[0]
    clo = np.where((profile_nll <= 1) & (np.roll(profile_nll,1) > 1))[0]
    cv, uv, lv = t12_vec[np.argmin(profile_nll)], t12_vec[cup], t12_vec[clo]
    plt.plot(t12_vec, profile_nll, 'k', label="Fit = $%.1f^{+%.1f}_{-%.1f}$ hr"%(cv, uv-cv, cv-lv))
    plt.ylim(0, 10)
    levels = [1, 4, 9]
    for lidx, l in enumerate(levels):
        plt.plot(t12_vec, l*np.ones_like(t12_vec), 'k--', alpha=0.5)
        plt.text(12, l+0.2, "$%d\sigma$"%(lidx+1), fontsize=9, color='gray')
    plt.plot([t12_true, t12_true], [0, 10], 'b:', label="True value = %.1f hr"%t12_true)
    plt.xlim(5,30)
    plt.xlabel("Half-life, $T_{1/2}$ [hr]")
    plt.ylabel("2 $\Delta$NLL")
    plt.legend(loc="upper right")
    plt.title(labs[j])

    plt.figure(fig2d.number)
    plt.subplot(1,2,j+1)
    plt.pcolormesh(N0_vec, t12_vec, 2*nlls[j].T, cmap='viridis', vmin=0, vmax=12)
    plt.colorbar(label="2 $\Delta$NLL")
    min_loc = np.argmin(nlls[j].T)
    N0_mesh, t12_mesh = np.meshgrid(N0_vec, t12_vec)
    plt.plot( np.ndarray.flatten(N0_mesh)[min_loc], np.ndarray.flatten(t12_mesh)[min_loc], 
             'ro', label="Best fit")

    plt.contour( N0_vec, t12_vec, 2*nlls[j].T, levels=[2.3, 6.17, 11.8], colors='w')
    plt.xlabel("Initial number of nuclei, $N_0$")
    plt.ylabel("Half-life, $T_{1/2}$ [hr]")
    plt.plot(N0_vec, t12_true*np.ones_like(N0_vec), 'k:', label="True value = %.1f hr"%t12_true)
    plt.title(labs[j])

    ## plot the profile
    plt.plot(profile, t12_vec, 'r--', label= "Profile")
    bpN0, bpt12 = np.ndarray.flatten(N0_mesh)[min_loc], np.ndarray.flatten(t12_mesh)[min_loc]
    bpN0_lo, bpt12_lo = profile[clo], t12_vec[clo]
    bpN0_hi, bpt12_hi = profile[cup], t12_vec[cup]
    params_from_profile.append([bpN0, bpt12, bpN0_lo, bpt12_lo, bpN0_hi, bpt12_hi])

    plt.legend(loc='lower right', fontsize=9)

#plt.figure(fig1d.number)
#plt.savefig(plots_dir+"/profile_1d_%s.png"%file_label, dpi=300, bbox_inches="tight")
plt.figure(fig2d.number)
plt.savefig(plots_dir+"/profile_2d_%s.png"%file_label, dpi=300, bbox_inches="tight")

plt.show()

# %%
nbins = int(tot_livetime/3) + 2

decay_times_list = [decay_times,] # big_decay_times]

plt.figure(figsize=(6,5))
for j in range(1):
    hh,be = np.histogram(decay_times_list[j], bins=nbins, range=(0,int(time_hours[-1])))
    bc = be[:-1] + np.diff(be)/2

    bin_length = be[1]-be[0]

    #plt.subplot(1,2,j+1)
    plt.errorbar( bc, hh, yerr=np.sqrt(hh), fmt='ko', label="Data")
    curr_bp = params_from_profile[j]
    xx = np.linspace(0,time_hours[-1],1000)
    yy = np.log(2)*bin_length*curr_bp[0]/curr_bp[1] * 0.5**(xx/curr_bp[1])
    ylo = np.log(2)*bin_length*curr_bp[2]/curr_bp[3] * 0.5**(xx/curr_bp[3])
    yhi = np.log(2)*bin_length*curr_bp[4]/curr_bp[5] * 0.5**(xx/curr_bp[5])

    plt.plot(xx, yy, color='orange', label="Fit +/- 1$\sigma$")
    plt.fill_between(xx, ylo, yhi, color='orange', alpha=0.2, edgecolor=None)
    #plt.errorbar( bc, hh2, yerr=np.sqrt(hh2), fmt='o', color='orange', markerfacecolor='None', label="Recon $\geq$6$e$")
    #fill_dps()
    plt.xlabel("Time since start [hours]")
    plt.ylabel("Counts/(%.1f hours)"%(bin_length))
    plt.xlim(0,time_hours[-1])
    plt.title(labs[j])
    plt.legend()

plt.savefig(plots_dir+"/decays_vs_time_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
plt.figure(figsize=(14,10))
for j in range(1):
    hh,be = np.histogram(decay_times_list[j], bins=nbins, range=(0,int(time_hours[-1])))
    bc = be[:-1] + np.diff(be)/2

    bin_length = be[1]-be[0]

    plt.subplot(2,1,j+1)
    plt.errorbar( bc, hh, yerr=np.sqrt(hh), fmt='ko', label="Data")
    curr_bp = params_from_profile[j]
    xx = np.linspace(0,time_hours[-1],1000)
    yy = np.log(2)*bin_length*curr_bp[0]/curr_bp[1] * 0.5**(xx/curr_bp[1])
    ylo = np.log(2)*bin_length*curr_bp[2]/curr_bp[3] * 0.5**(xx/curr_bp[3])
    yhi = np.log(2)*bin_length*curr_bp[4]/curr_bp[5] * 0.5**(xx/curr_bp[5])

    plt.plot(xx, yy, color='orange', label="Fit +/- 1$\sigma$")
    plt.fill_between(xx, ylo, yhi, color='orange', alpha=0.2, edgecolor=None)
    #plt.errorbar( bc, hh2, yerr=np.sqrt(hh2), fmt='o', color='orange', markerfacecolor='None', label="Recon $\geq$6$e$")
    #fill_dps()
    plt.xlabel("Time since start [hours]")
    plt.ylabel("Counts/(%.1f hours)"%(bin_length))
    plt.xlim(0,time_hours[-1])
    plt.title(labs[j])
    plt.legend()

plt.subplot(2,1,2)
plt.plot(time_hours[1:], corr_vec[1:,corr_idx]/cal_fac, 'k-', label="Correlation")
plt.plot(time_hours[1:], running_charge, '-', color='orange', label="Recon. charge")
plt.grid(True)
fill_dps(dead_period_edges)
fill_dps(lamp_period_edges, 'black', lab="UV lamp")
fill_dps(filament_period_edges, 'red', lab="Filament")
plt.xlim(time_hours[0], time_hours[-1])
plt.xlabel("Time since start [hours]")
plt.ylabel("Net charge [$e$]")
plt.legend(loc="lower right")
plt.xlim(0,time_hours[-1])

plt.savefig(plots_dir+"/decays_vs_time_with_charge_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
def exp_fun(x, A, t12=10.6):
    lam = np.log(2)/t12
    return A*np.exp(-lam*x)

# %%
time_between = np.diff(good_change_list[:,0])

plt.figure(figsize=(6,5))
plt.semilogy(good_change_list[:,0][:-1], time_between*60, 'ko')
plt.xlim(0,time_hours[-1])
plt.ylim(0.1,1e3)
t12_tl208 = 3.1
for i in range(1,4):
    plt.plot([0,time_hours[-1]], [i*t12_tl208, i*t12_tl208], 'k:', alpha=0.5)
    if(i==1):
        plt.text(time_hours[-1]*0.9, i*t12_tl208*1.1, r"$%d \times T_{1/2}^{208Tl}$"%(i), fontsize=9, color='k')
    else:
        plt.text(time_hours[-1]*0.9, i*t12_tl208*1.1, r"$%d \times$"%(i), fontsize=9, color='k')

xcut, ycut = 10, 6.2

all_times = good_change_list[:,0][:-1]
cut_pos = (all_times > xcut) & (time_between*60 < ycut)
bi_decay_times = all_times[cut_pos]
cand_decay_times = all_times[np.roll(cut_pos,1)]


plt.plot( [xcut,xcut], [0.1, ycut], 'b')
plt.plot( [xcut,time_hours[-1]], [ycut, ycut], 'b')
plt.xlabel("Time since start [hours]")
plt.ylabel("Time between decays [minutes]")

plt.savefig(plots_dir+"/time_between_tl208_%s.png"%file_label, dpi=300, bbox_inches="tight")

plt.show()

# %%
tbins = np.linspace(6,200,20)
hh, be = np.histogram(time_between*60, bins=tbins)
bc = be[:-1] + np.diff(be)/2
bsize_orig = be[1]-be[0]

err = np.sqrt(hh)
err[err==0] = 1
bp, bcov = opt.curve_fit(exp_fun, bc, hh, p0=[20, 20], sigma=err)
print("T12 = %.1f +/- %.1f"%(bp[1], np.sqrt(bcov[1,1])))
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.errorbar(bc, hh, yerr=np.sqrt(hh), fmt='ko')
plt.plot(bc, exp_fun(bc, *bp), 'r')
plt.gca().set_yscale("log")
plt.ylim(0.1,100)
plt.xlabel("Time between decays [m]")
plt.ylabel("Counts")
plt.title("Time between decays (all data)")

plt.subplot(1,2,2)
tbins = np.linspace(0,60,20)
hh, be = np.histogram(time_between*60, bins=tbins)
bc = be[:-1] + np.diff(be)/2

bsize_fac = (be[1]-be[0])/bsize_orig
plt.errorbar(bc, hh, yerr=np.sqrt(hh), fmt='ko')
plt.plot(bc, exp_fun(bc, *bp)*bsize_fac, 'r')
#plt.gca().set_yscale("log")
plt.ylim(0,20)
plt.xlabel("Time between decays [m]")
plt.ylabel("Counts")
plt.title("Time between decays (zoom to short times)")

plt.savefig(plots_dir+"/time_between_fits_%s.png"%file_label, dpi=300, bbox_inches="tight")
plt.show()
# Out:
# T12 = 24.0 +/- 3.9

# %%
## now find the Tl-208 candidate decays and plot a zoom

nrows = int(len(cand_decay_times)/2) + 1

low_wind, high_wind = 2, 2
hrs_to_mins = 60

plt.figure(figsize=(12,nrows*5))
figidx = 1
for bi_hrs,cdt_hrs in zip(bi_decay_times,cand_decay_times):

    cdt = cdt_hrs*hrs_to_mins
    cdt_bi = bi_hrs*hrs_to_mins

    idx_of_bi = np.argmin(np.abs(time_hours[1:]*hrs_to_mins - cdt_bi))
    bi_time = time_hours[1:][idx_of_bi]*hrs_to_mins
    print(idx_of_bi)

    plt.subplot(nrows,2,figidx)
    plt.plot(time_hours[1:]*hrs_to_mins, corr_vec[1:,corr_idx]/cal_fac, 'k-', label="Correlation")
    plt.plot(time_hours[1:]*hrs_to_mins, running_charge, '-', color='orange', label="Recon. charge")
    plt.grid(True)
    gpts = (time_hours[1:]*hrs_to_mins > cdt_bi-low_wind) & (time_hours[1:]*hrs_to_mins < cdt+high_wind)
    y1, y2 = np.min(running_charge[gpts])-5, np.max(running_charge[gpts])+10
    plt.ylim(y1,y2)
    fill_dps(dead_period_edges)
    fill_dps(lamp_period_edges, 'black', lab="UV lamp")
    fill_dps(filament_period_edges, 'red', lab="Filament")
    plt.xlim(cdt_bi-low_wind, cdt+high_wind)


    for i in range(1,4):
        plt.fill_between([bi_time+(i-1)*t12_tl208, bi_time+i*t12_tl208], [y1, y1], [y2, y2], color='k', alpha=0.4-(i*0.09),edgecolor=None)
        xp = np.mean([bi_time+(i-1)*t12_tl208, bi_time+i*t12_tl208])
        if(xp > cdt+high_wind): break
        plt.text(xp, y2-1, r"$%d \times$"%i +"\n$T_{1/2}$", fontsize=9, color='k', verticalalignment='top', horizontalalignment='center')
    plt.xlabel("Time since start [mins]")
    plt.ylabel("Net charge [$e$]")
    figidx+=1
    #plt.legend(loc="upper left")
    plt.savefig(plots_dir+"/candidate_bi_tl_%s.png"%file_label, dpi=300, bbox_inches="tight")
# Out:
# 11270

# %% [markdown]
# Now let's analyze whether there are any kicks correlated with the charge changes:

# %%
## create list of calibration files 
calib_file_dict = {}
coords_to_calib = ['x', 'y', 'z']

for curr_path in calib_data:

    for coord in coords_to_calib:
        fpath = os.path.join(base_path, curr_path, coord, "**MeV/*.h5")
        curr_file_list = natsorted(glob.glob(fpath, recursive=True))

        for file in curr_file_list:
            impulse_amp = bu.parse_impulse_amplitude(file)

            if( coord in calib_file_dict.keys()):            
                if impulse_amp in calib_file_dict[coord].keys():
                    calib_file_dict[coord][impulse_amp].append(file)
                else:
                    calib_file_dict[coord][impulse_amp] = [file,] 
            else:
                calib_file_dict[coord] = {}
                calib_file_dict[coord][impulse_amp] = [file,]

noise_file_list = []
for curr_path in calib_noise_path:
    curr_file_list = natsorted(glob.glob(os.path.join(base_path, curr_path, "*.h5"), recursive=True))
    if(len(noise_file_list)>0):
        noise_file_list += curr_file_list
    else:
        noise_file_list = curr_file_list

## no dedicated noise, so sample from throughout the run
if(len(noise_file_list) == 0):
    noise_file_list = data_list[::100]

# %%
# calculate the pulse tempates by averaging all calibration files
importlib.reload(bu)
drive_dict = {'x': 8, 'y': 11, 'z': 9} ## different drive columns for this data
lowpass_dict = {'x': 400, 'y': 400, 'z': 1000} ## bad noise at high freq not averaging for this sphere
fit_pars_dict = {'x': [-1,2*np.pi*30,10,0.20],
                 'y': [-1,2*np.pi*70,10,0.20],
                 'z': [-1,2*np.pi*120,30,0.20]}
template_dict, template_dict_fit, fit_vals, norm_dict = bu.get_average_template_3D(calib_file_dict, make_plots=True,
                                                                        fit_pars=fit_pars_dict, drive_idx=-1, drive_dict=drive_dict, 
                                                                        lowpass_dict=lowpass_dict)
plt.savefig(plots_dir+"/template_fits_%s.png"%file_label, dpi=300, bbox_inches="tight")

## plot with smaller x range
_, _, _, _ = bu.get_average_template_3D(calib_file_dict, make_plots=True, fit_pars=fit_pars_dict, 
                                     drive_idx=-1, drive_dict=drive_dict, xrange=[0.15, 0.35], lowpass_dict=lowpass_dict)
plt.savefig(plots_dir+"/template_fits_zoom_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
template_fit_vals = fit_vals
coord_list = ['x', 'y', 'z']
print("Coord\tf_0 [Hz]\tgamma/(2pi) [Hz]")
for coord in coord_list:
    fp = fit_vals[coord][coord]
    print("%s\t%.1f\t\t%.1f"%(coord, fp[1]/(2*np.pi), fp[2]/(2*np.pi)))
# Out:
# Coord	f_0 [Hz]	gamma/(2pi) [Hz]
# x	38.2		4.2
# y	61.1		7.8
# z	280.1		147.7

# %%
## using the above, we can calibrate into volts per meters
volts_per_meters = {}
MeV_to_kgms = 5.34e-22 ## 1 MeV in kg*m/s
msphere = 2.5e-14 ## 3 um sphere @ 1.8 g/cm^3 in kg
for coord in coord_list:
    fp = fit_vals[coord][coord]
    omega0, gam = fp[1], fp[2]
    omega1 = np.sqrt( omega0**2 - gam**2 )
    t = np.linspace(0, 10/(omega0/(2*np.pi)), 1000) ## 10 periods
    p0 = norm_dict[coord + "_amp"] * MeV_to_kgms
    volts_per_meters[coord] = norm_dict[coord]/(p0*np.max(np.exp(-gam*t)*np.sin(omega1*t))/(msphere*omega1))
    #print(volts_per_meters[coord])
    print("Max motion for 250 MeV [nm]: ", p0*np.max(np.exp(-gam*t)*np.sin(omega1*t))/(msphere*omega1)*1e9)
# Out:
# Max motion for 250 MeV [nm]:  18.93000220195299
# Max motion for 250 MeV [nm]:  11.53846833996384
# Max motion for 250 MeV [nm]:  1.6161329623833276

# %%
def clean_axes(arr):
    plt.gca().set_xticks([0,1,2])
    plt.gca().set_yticks([0,1,2])
    plt.gca().set_xticklabels(['x', 'y', 'z'])
    plt.gca().set_yticklabels(['x', 'y', 'z'])
    plt.xlabel("Drive direction")
    plt.ylabel("Response direction")
    plt.colorbar(label="Normalized amplitude")

    for i in range(np.shape(arr)[0]):
        for j in range(np.shape(arr)[1]):
            if(arr[i,j]>0.9):
                plt.text(j,i,"%.1f"%arr[i,j],color='white',ha='center',va='center')
            else:
                plt.text(j,i,"%.1f"%arr[i,j],color='k',ha='center',va='center')

# %%
## now make a plot of the cross talk (separately for force and for imaging for each)
plt.figure(figsize=(15, 5))

## imaging crosstalk
xtalk_arr = np.zeros((len(coord_list), len(coord_list)))
plt.subplot(1,3,1)
for j, drive_coord in enumerate(coord_list):
    for k, resp_coord in enumerate(coord_list):
        if(j == k): 
            xtalk_arr[k, j] = 1
        else:
            xtalk_arr[k, j] = fit_vals[drive_coord][resp_coord][j]

print(xtalk_arr)
plt.imshow(np.abs(xtalk_arr), vmin=0, vmax=1, cmap='Blues')
clean_axes(xtalk_arr)
plt.title("Imaging cross talk")

## force crosstalk
force_arr = np.zeros((len(coord_list), len(coord_list)))
plt.subplot(1,3,2)
for j, drive_coord in enumerate(coord_list):
    for k, resp_coord in enumerate(coord_list):
        if(j == k): 
            force_arr[k, j] = 1
        else:
            force_arr[k, j] = fit_vals[drive_coord][resp_coord][k]

plt.imshow(np.abs(force_arr), vmin=0, vmax=1, cmap="Blues")
clean_axes(force_arr)
plt.title("Force cross talk (same coord)")

## force crosstalk (other coord)
force_arr = np.zeros((len(coord_list), len(coord_list)))
plt.subplot(1,3,3)
for j, drive_coord in enumerate(coord_list):
    for k, resp_coord in enumerate(coord_list):
        if(j == k): 
            force_arr[k, j] = 1
        else:
            other_coord = [0,1,2]
            other_coord.remove(k)
            other_coord.remove(j)
            force_arr[k, j] = fit_vals[drive_coord][resp_coord][other_coord]

plt.imshow(np.abs(force_arr), vmin=0, vmax=1, cmap="Blues")
clean_axes(force_arr)
plt.title("Force cross talk (other coord)")
plt.savefig(plots_dir+"/cross_talk_mats_%s.png"%file_label, dpi=300, bbox_inches="tight")
# Out:
# [[ 1.         -0.42751067  0.0165665 ]
#  [-0.4670755   1.         -0.1455866 ]
#  [-0.23183501  0.13064683  1.        ]]

# %%
## noise from the same time as the calibration

remake_files = True

res_pars = [fit_vals['x']['x'][1], fit_vals['x']['x'][2]]

if(remake_files):
    importlib.reload(bu)

    noise_dict = bu.get_noise_template(noise_file_list, res_pars=res_pars, nfft=2**16)

# %%
remake_files = True

if(remake_files):
    importlib.reload(bu)

    ## was 115
    range_dict = {'x': [5,80], 'y': [5,200], 'z': [50, 500]}

    noise_dict_3D = bu.get_noise_template_3D(noise_file_list, fit_vals, range_dict, nfft=2**16)

    plt.savefig(plots_dir+"/noise_3D_%s.png"%file_label, dpi=300, bbox_inches="tight")
# Out:
# 257
# 414
# 1835

# %%
importlib.reload(bu)
drive_idx = 8
opt_filt_amps, phi_t = bu.optimal_filt(calib_file_dict['x'], {250.0: template_dict_fit['x']['x']}, noise_dict, time_offset=-12, drive_idx=drive_idx, cal_fac=288.5, make_plots=False)
time_corr_amps = bu.correlation_filt(calib_file_dict['x'], {250.0: template_dict_fit['x']['x']}, bandpass=[5,70], notch_list = [], drive_idx=drive_idx, make_plots=False)
bandpass_amps = bu.bandpass_filt(calib_file_dict['x'], {250.0: template_dict_fit['x']['x']}, time_offset=0, bandpass=[5,70], drive_idx=drive_idx, cal_fac = 7550, make_plots=False)
# Out:
# /Users/dcmoore/Library/CloudStorage/GoogleDrive-david.c.moore@yale.edu/My Drive/yale/uspheres/decay_analysis/bead_utils.py:1107: RuntimeWarning: invalid value encountered in sqrt

# %%
importlib.reload(bu)
## calculate pedestal with search bias by time offset away from pulse
opt_filt_pedestal, _ = bu.optimal_filt(calib_file_dict['x'], {250.0: template_dict_fit['x']['x']}, noise_dict, time_offset=2000, drive_idx=drive_idx, cal_fac=288.5, make_plots=False)
bandpass_pedestal = bu.bandpass_filt(calib_file_dict['x'], {250.0: template_dict_fit['x']['x']}, time_offset=-500, bandpass=[5,70], drive_idx=drive_idx, cal_fac = 7550, make_plots=False)

# %%
importlib.reload(bu)
opt_filt_amps_1D = bu.optimal_filt_1D(calib_file_dict, template_dict_fit, noise_dict_3D, time_offset=8, do_lp_filt=True,
                   drive_dict=drive_dict, cal_fac=4.2e-8, make_plots=False, coord='x') 
opt_filt_amps_1D_y = bu.optimal_filt_1D(calib_file_dict, template_dict_fit, noise_dict_3D, time_offset=8, do_lp_filt=True,
                   drive_dict=drive_dict, cal_fac=1.5e-7, make_plots=False, coord='y') 
opt_filt_amps_1D_z = bu.optimal_filt_1D(calib_file_dict, template_dict_fit, noise_dict_3D, time_offset=8, do_lp_filt=True,
                        drive_dict=drive_dict, cal_fac=1.5e-7 * 200, make_plots=False, coord='z')
# Out:
# /Users/dcmoore/Library/CloudStorage/GoogleDrive-david.c.moore@yale.edu/My Drive/yale/uspheres/decay_analysis/bead_utils.py:1368: RuntimeWarning: invalid value encountered in sqrt

# %%
importlib.reload(bu)
opt_filt_amps_3D = bu.optimal_filt_3D(calib_file_dict, template_dict_fit, noise_dict_3D, time_offset=8, 
                drive_dict=drive_dict, make_plots=False, noise_scale=[1,0.167,0.167])

# %%
## compare various recon methods
amp_bins = np.arange(0,100,1.5)

def gauss_fun(x,A,mu,sig):
    return A*np.exp(-(x-mu)**2/(2*sig**2))

fit_vals = []

amp_dicts = [time_corr_amps, bandpass_amps, opt_filt_amps_1D, opt_filt_amps_3D['x']]
amp_methods = ["Time correlation", "Simple bandpass", "Optimal filter", "Optimal filter (3D)"]
amp_cal_facs = [106.8, 6889, 1.057e-5, 1.057e-5] ## set by hand to match the calibration data  ##91.2, 
amp_colors = ['b', 'r', 'orange', 'g']

ymax = 300

plt.figure(figsize=(6,5))    
for i,filt_amps in enumerate(amp_dicts):
    first_amp = True
    for j,amp in enumerate(filt_amps.keys()):
        if( not isinstance(amp, numbers.Number)): continue
        if(not first_amp): continue
        first_amp = False
        amp_bins = np.linspace(0,2*amp,60)
        ca = filt_amps[amp]*amp_cal_facs[i]
        gpts = (ca>0)
        amp_scale = amp/np.median(ca[gpts])
        hh,be = np.histogram(ca*amp_scale, bins=amp_bins)
        bc = be[:-1] + np.diff(be)/2

        ## gauss fit
        err = np.sqrt(hh)
        err[err==0] = 1
        gp, gcov = opt.curve_fit(gauss_fun, bc, hh, sigma=err, p0=[1, amp, 50])

        ## amplitude, mean, mean_err, sig, sig_err
        fit_vals.append([amp, gp[1], np.sqrt(gcov[1,1]), np.abs(gp[2]), np.sqrt(gcov[2,2]), i])

        #plt.subplot(3,3,j+1)
        plt.errorbar(bc, hh, yerr=np.sqrt(hh), fmt='o', color=amp_colors[i])
        plt.plot(bc, gauss_fun(bc, *gp), amp_colors[i], label="$\mu$ = %.1f MeV,\n$\sigma$=%.1f MeV"%(gp[1], gp[2]))
        plt.title("Amplitude = %d MeV"%amp)
        plt.ylabel("Counts")
        plt.xlabel("Reconstructed amplitude [MeV]")

        plt.text(15, ymax-(ymax/15)*(i+1), amp_methods[i], fontsize=12, color=amp_colors[i])

        #plt.suptitle(amp_methods[i])
        plt.legend()

    plt.ylim(0,ymax)
    plt.savefig(plots_dir+"/calib_reconstructed_amplitudes_%s.png"%file_label, dpi=300)

# %%
fit_vals_offset = []

ymax = 200

plt.figure(figsize=(6,5))    
for i,filt_amps in enumerate(amp_dicts):

    for j,amp in enumerate(filt_amps.keys()):
        if( isinstance(amp, numbers.Number)): continue
        if(amp in ['x','y','z']): continue
        amp_val = float(amp.split("_")[0])

        cent_time = np.median(filt_amps[amp])
        offset_bins = np.arange(cent_time-100,cent_time + 100,2) 

        hh,be = np.histogram(filt_amps[amp], bins=offset_bins)
        bc = be[:-1] + np.diff(be)/2

        ## gauss fit
        err = np.sqrt(hh)
        err[err==0] = 1
        gp, gcov = opt.curve_fit(gauss_fun, bc, hh, sigma=err, p0=[1, np.median(filt_amps[amp]), np.std(filt_amps[amp])])

        ## amplitude, mean, mean_err, sig, sig_err
        fit_vals_offset.append([amp, gp[1], np.sqrt(gcov[1,1]), np.abs(gp[2]), np.sqrt(gcov[2,2]), i])

        #plt.subplot(3,3,j+1)
        plt.errorbar(bc, hh, yerr=np.sqrt(hh), fmt='o', color=amp_colors[i])
        plt.plot(bc, gauss_fun(bc, *gp), amp_colors[i], label="$\mu$ = %.1f ADC,\n$\sigma$=%.1f ADC"%(gp[1], gp[2]))
        plt.title("Time offset, Amplitude = %d MeV"%amp_val)
        plt.ylabel("Counts")
        plt.xlabel("Reconstructed time offset [ADC bins = 0.1 ms]")
        plt.ylim(0,ymax)

        plt.text(-90, ymax-10*(i+1), amp_methods[i], fontsize=12, color=amp_colors[i])

        plt.legend()

# %%
## compare optimal filter in each coordinate
amp_bins = np.arange(0,100,1.5)

def gauss_fun(x,A,mu,sig):
    return A*np.exp(-(x-mu)**2/(2*sig**2))

fit_vals_xyz = []

amp_dicts = [opt_filt_amps_1D, opt_filt_amps_1D_y, opt_filt_amps_1D_z]
amp_methods = ["X direction", "Y direction", "Z direction"]
amp_cal_facs = [1.057e-5, 3.76e-5, 4.71e-5] ## set by hand to match the calibration data
amp_colors = ['b', 'r', 'orange', 'g']

ymax = 350

calibrated_OF_amps_from_fit = np.zeros(3)

plt.figure(figsize=(21,5))    
for i,filt_amps in enumerate(amp_dicts):

    cidx = 0
    for j,amp in enumerate(filt_amps.keys()):
        if( not isinstance(amp, numbers.Number)): continue
        if(amp == 250):
            amp_bins = np.linspace(0,2*amp,60)
        else:
            amp_bins = np.linspace(0,2*amp,40)

        ca = filt_amps[amp]*amp_cal_facs[i]
        amp_scale = amp/np.median(ca[ca>0])
        calibrated_OF_amps_from_fit[i] = amp_scale*amp_cal_facs[i]
        hh,be = np.histogram(ca*amp_scale, bins=amp_bins)
        bc = be[:-1] + np.diff(be)/2

        ## gauss fit
        err = np.sqrt(hh)
        err[err==0] = 1
        gp, gcov = opt.curve_fit(gauss_fun, bc, hh, sigma=err, p0=[1, amp, 50])

        ## amplitude, mean, mean_err, sig, sig_err
        fit_vals_xyz.append([amp, gp[1], np.sqrt(gcov[1,1]), np.abs(gp[2]), np.sqrt(gcov[2,2]), i])

        plt.subplot(1,4,i+1)
        plt.errorbar(bc, hh, yerr=np.sqrt(hh), fmt='o', color=amp_colors[cidx])
        plt.plot(bc, gauss_fun(bc, *gp), amp_colors[cidx], label="$\mu$ = %.1f MeV,\n$\sigma$=%.1f MeV"%(gp[1], gp[2]))
        #plt.title("Amplitude = %d MeV"%amp)
        plt.ylabel("Counts")
        plt.xlabel("Reconstructed amplitude [MeV]")

        plt.text(15, ymax-(ymax/15)*(i+1), amp_methods[i], fontsize=12, color=amp_colors[i])
        cidx += 1

        #plt.suptitle(amp_methods[i])
        plt.legend()

    plt.ylim(0,ymax)

fit_vals_xyz = np.array(fit_vals_xyz)
plt.subplot(1,4,4)
for i,filt_amps in enumerate(amp_dicts):
    gpts = fit_vals_xyz[:,-1] == i
    plt.errorbar(fit_vals_xyz[gpts,0], fit_vals_xyz[gpts,3], yerr=fit_vals_xyz[gpts,4], fmt='o', color=amp_colors[i], label=amp_methods[i])
plt.xlim(0,1100)
plt.ylim(0,300)
plt.legend(loc='upper left')
plt.xlabel("Calibration amplitude [MeV]")
plt.ylabel("Reconstructed resolution, $\sigma$ [MeV]")

plt.savefig(plots_dir+"/calib_reconstructed_dirs_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
## off diagonal elements
importlib.reload(bu)
opt_fit_1d_mat = {}
coord_list = ['x', 'y', 'z']
for dc in coord_list:
    opt_fit_1d_mat[dc] = {}
    for rc  in coord_list:
        opt_fit_1d_mat[dc][rc] = bu.optimal_filt_1D(calib_file_dict, template_dict_fit, noise_dict_3D, time_offset=8, 
                                                    drive_dict=drive_dict, cal_fac=1, make_plots=False, coord=dc, resp_coord=rc)

# %%
## compare optimal filter in each coordinate
amp_bins = np.arange(0,100,1.5)

def gauss_fun(x,A,mu,sig):
    return A*np.exp(-(x-mu)**2/(2*sig**2))

fit_vals_xyz = []

coords = ['x', 'y', 'z']
amp_dicts = [opt_fit_1d_mat, opt_filt_amps_3D]
amp_methods = ["X direction", "Y direction", "Z direction"]
amp_cal_facs = [1.057e-5, 3.76e-5, 4.71e-5] ## set by hand to match the calibration data
amp_colors = ['b', 'r', 'orange', 'g']
alg_list = ['1D', '3D']

ymax = 300

plt.figure(figsize=(14,15))    
for i,coord in enumerate(coords):
    for l,resp_coord in enumerate(coords):   

        for k,alg in enumerate(alg_list):
            filt_amps = amp_dicts[k][coord][resp_coord]

            for j,amp in enumerate(filt_amps.keys()):
                if( not isinstance(amp, numbers.Number)): continue
                if(j > 0):
                    continue
                if(coord==resp_coord):
                    if(amp == 250):
                        amp_bins = np.linspace(0,2*amp,60)
                    else:
                        amp_bins = np.linspace(0,2*amp,40)
                else:
                    amp_bins = np.linspace(-2*amp,2*amp,2*60)     

                ca = filt_amps[amp]*amp_cal_facs[i]
                amp_scale = amp/np.median(amp_dicts[k][coord][coord][amp]*amp_cal_facs[i])
                hh,be = np.histogram(ca*amp_scale, bins=amp_bins)
                bc = be[:-1] + np.diff(be)/2

                ## gauss fit
                err = np.sqrt(hh)
                err[err==0] = 1
                try:
                    gp, gcov = opt.curve_fit(gauss_fun, bc, hh, sigma=err, p0=[1, np.median(ca*amp_scale), np.std(ca*amp_scale)])
                except:
                    gp = [1, np.median(ca*amp_scale), np.std(ca*amp_scale)]
                    gcov = np.ones((3,3))*np.inf

                ## amplitude, mean, mean_err, sig, sig_err
                fit_vals_xyz.append([amp, gp[1], np.sqrt(gcov[1,1]), np.abs(gp[2]), np.sqrt(gcov[2,2]), i])

                sidx = 3*l + i + 1
                plt.subplot(3,3,sidx)
                plt.errorbar(bc, hh, yerr=np.sqrt(hh), fmt='o', color=amp_colors[k])
                plt.plot(bc, gauss_fun(bc, *gp), amp_colors[k], label="$\mu$ = %.1f MeV,\n$\sigma$=%.1f MeV"%(gp[1], gp[2]))
                #plt.title("Amplitude = %d MeV"%amp)
                plt.ylabel("Counts")
                plt.xlabel("Reconstructed amplitude [MeV]")

                plt.text(15, ymax-15*(k+1), alg_list[k], fontsize=12, color=amp_colors[k])

                plt.title("Drive = %s, Response = %s"%(coords[i], coords[l]))
                plt.legend()
                plt.xlim(-200,2*amp)

            plt.ylim(0,ymax)


plt.savefig(plots_dir+"/calib_1D3D_dirs_%s.png"%file_label, dpi=300, bbox_inches="tight")

# %%
remake_files = True

if(remake_files):
    nsegs = 2**6 ## number of segments to chop up for Welch's method
    cdat, attr, fhandle = bu.get_data(data_list[0])
    nps = int(len(cdat[:,0])/nsegs)

    files_to_use = data_list
    noise_arr = np.zeros((len(files_to_use), int(nps/2)+1))
    time_arr = np.zeros(len(files_to_use))
    for i,f in enumerate(files_to_use):

        if(i%10 == 0): print("working on file %d: %s"%(i, f))
        
        cdat, attr, fhandle = bu.get_data(f)
        if(not fhandle):
            continue    

        xdata = cdat[:,0]
        cf, cpsd = sig.welch(xdata, fs=attr['Fsamp'], nperseg=nps)
        
        noise_arr[i,:] = cpsd
        time_arr[i] = attr["Time"]

    freqs = cf
    time_arr -= time_arr[0] # time since start
    time_arr /= 3600 ## convert to hours
    np.savez(os.path.join(data_dir, "noise_data_vs_time.npz"), noise_arr=noise_arr, time_arr=time_arr, freqs=freqs)
else:
    npzfile = np.load(os.path.join(data_dir, "noise_data_vs_time.npz"))
    noise_arr = npzfile['noise_arr']
    time_arr = npzfile['time_arr']
    freqs = npzfile['freqs']
# Out:
# working on file 0: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_0.h5
# working on file 10: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_10.h5
# working on file 20: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_20.h5
# working on file 30: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_30.h5
# working on file 40: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_40.h5
# working on file 50: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_50.h5
# working on file 60: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_60.h5
# working on file 70: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_70.h5
# working on file 80: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_80.h5
# working on file 90: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_90.h5
# working on file 100: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_100.h5
# working on file 110: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_110.h5
# working on file 120: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_120.h5
# working on file 130: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_130.h5
# working on file 140: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_140.h5
# working on file 150: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_150.h5
# working on file 160: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_160.h5
# working on file 170: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_170.h5
# working on file 180: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_180.h5
# working on file 190: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_190.h5
# working on file 200: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_200.h5
# working on file 210: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_210.h5
# working on file 220: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_220.h5
# working on file 230: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_230.h5
# working on file 240: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_240.h5
# working on file 250: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_250.h5
# working on file 260: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_260.h5
# working on file 270: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_270.h5
# working on file 280: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_280.h5
# working on file 290: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_290.h5
# working on file 300: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_300.h5
# working on file 310: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_310.h5
# working on file 320: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_320.h5
# working on file 330: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_330.h5
# working on file 340: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_340.h5
# working on file 350: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_350.h5
# working on file 360: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_360.h5
# working on file 370: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_370.h5
# working on file 380: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_380.h5
# working on file 390: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_390.h5
# working on file 400: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_400.h5
# working on file 410: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_410.h5
# working on file 420: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_420.h5
# working on file 430: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_430.h5
# working on file 440: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_440.h5
# working on file 450: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_450.h5
# working on file 460: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_460.h5
# working on file 470: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_470.h5
# working on file 480: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_480.h5
# working on file 490: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_490.h5
# working on file 500: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_500.h5
# working on file 510: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_510.h5
# working on file 520: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_520.h5
# working on file 530: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_530.h5
# working on file 540: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_540.h5
# working on file 550: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_550.h5
# working on file 560: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_560.h5
# working on file 570: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_570.h5
# working on file 580: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_580.h5
# working on file 590: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_590.h5
# working on file 600: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_600.h5
# working on file 610: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_610.h5
# working on file 620: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_620.h5
# working on file 630: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_630.h5
# working on file 640: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_640.h5
# working on file 650: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_650.h5
# working on file 660: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_660.h5
# working on file 670: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_670.h5
# working on file 680: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_680.h5
# working on file 690: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_690.h5
# working on file 700: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_700.h5
# working on file 710: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_710.h5
# working on file 720: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_720.h5
# working on file 730: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_730.h5
# working on file 740: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_740.h5
# working on file 750: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_750.h5
# working on file 760: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_760.h5
# working on file 770: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_770.h5
# working on file 780: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_780.h5
# working on file 790: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_790.h5
# working on file 800: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_800.h5
# working on file 810: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_810.h5
# working on file 820: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_820.h5
# working on file 830: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_830.h5
# working on file 840: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_840.h5
# working on file 850: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_850.h5
# working on file 860: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_860.h5
# working on file 870: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_870.h5
# working on file 880: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_880.h5
# working on file 890: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_890.h5
# working on file 900: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_8.h5
# working on file 910: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_18.h5
# working on file 920: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_28.h5
# working on file 930: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_38.h5
# working on file 940: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_48.h5
# working on file 950: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_58.h5
# working on file 960: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_68.h5
# working on file 970: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_78.h5
# working on file 980: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_88.h5
# working on file 990: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_98.h5
# working on file 1000: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_108.h5
# working on file 1010: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_118.h5
# working on file 1020: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_128.h5
# working on file 1030: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_138.h5
# working on file 1040: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_148.h5
# working on file 1050: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_158.h5
# working on file 1060: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_168.h5
# working on file 1070: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_178.h5
# working on file 1080: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_188.h5
# working on file 1090: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_198.h5
# working on file 1100: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_208.h5
# working on file 1110: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_218.h5
# working on file 1120: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_228.h5
# working on file 1130: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_238.h5
# working on file 1140: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_248.h5
# working on file 1150: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_258.h5
# working on file 1160: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_268.h5
# working on file 1170: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_278.h5
# working on file 1180: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_288.h5
# working on file 1190: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_298.h5
# working on file 1200: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_308.h5
# working on file 1210: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_318.h5
# working on file 1220: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_328.h5
# working on file 1230: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_338.h5
# working on file 1240: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_348.h5
# working on file 1250: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_358.h5
# working on file 1260: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_368.h5
# working on file 1270: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_378.h5
# working on file 1280: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_388.h5
# working on file 1290: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_398.h5
# working on file 1300: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_408.h5
# working on file 1310: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_418.h5
# working on file 1320: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_428.h5
# working on file 1330: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_438.h5
# working on file 1340: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_448.h5
# working on file 1350: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_458.h5
# working on file 1360: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_468.h5
# working on file 1370: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_478.h5
# working on file 1380: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_488.h5
# working on file 1390: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_498.h5
# working on file 1400: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_508.h5
# working on file 1410: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_518.h5
# working on file 1420: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_528.h5
# working on file 1430: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_538.h5
# working on file 1440: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_548.h5
# working on file 1450: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_558.h5
# working on file 1460: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_568.h5
# working on file 1470: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_578.h5
# working on file 1480: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_588.h5
# working on file 1490: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_598.h5
# working on file 1500: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_608.h5
# working on file 1510: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_618.h5
# working on file 1520: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_628.h5
# working on file 1530: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_638.h5
# working on file 1540: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_648.h5
# working on file 1550: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_658.h5
# working on file 1560: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_668.h5
# working on file 1570: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_678.h5
# working on file 1580: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_688.h5
# working on file 1590: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_698.h5
# working on file 1600: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_708.h5
# working on file 1610: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_718.h5
# working on file 1620: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_728.h5
# working on file 1630: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_738.h5
# working on file 1640: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_748.h5
# working on file 1650: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_758.h5
# working on file 1660: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_768.h5
# working on file 1670: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_778.h5
# working on file 1680: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_788.h5
# working on file 1690: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_798.h5
# working on file 1700: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_808.h5
# working on file 1710: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_818.h5
# working on file 1720: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_828.h5
# working on file 1730: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_838.h5
# working on file 1740: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_848.h5
# working on file 1750: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_858.h5
# working on file 1760: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_868.h5
# working on file 1770: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_878.h5
# working on file 1780: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_888.h5
# working on file 1790: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_898.h5
# working on file 1800: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_908.h5
# working on file 1810: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_918.h5
# working on file 1820: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_928.h5
# working on file 1830: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_938.h5
# working on file 1840: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_948.h5
# working on file 1850: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_958.h5
# working on file 1860: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_968.h5
# working on file 1870: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_978.h5
# working on file 1880: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_988.h5
# working on file 1890: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_998.h5
# working on file 1900: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1008.h5
# working on file 1910: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1018.h5
# working on file 1920: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1028.h5
# working on file 1930: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1038.h5
# working on file 1940: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1048.h5
# working on file 1950: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1058.h5
# working on file 1960: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1068.h5
# working on file 1970: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1078.h5
# working on file 1980: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1088.h5
# working on file 1990: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1098.h5
# working on file 2000: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1108.h5
# working on file 2010: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1118.h5
# working on file 2020: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1128.h5
# working on file 2030: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1138.h5
# working on file 2040: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1148.h5
# working on file 2050: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1158.h5
# working on file 2060: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1168.h5
# working on file 2070: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1178.h5
# working on file 2080: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1188.h5
# working on file 2090: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1198.h5
# working on file 2100: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1208.h5
# working on file 2110: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1218.h5
# working on file 2120: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1228.h5
# working on file 2130: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1238.h5
# working on file 2140: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_4.h5
# working on file 2150: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_14.h5
# working on file 2160: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_24.h5
# working on file 2170: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_34.h5
# working on file 2180: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_44.h5
# working on file 2190: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_54.h5
# working on file 2200: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_64.h5
# working on file 2210: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_74.h5
# working on file 2220: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_84.h5
# working on file 2230: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_94.h5
# working on file 2240: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_104.h5
# working on file 2250: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_114.h5
# working on file 2260: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_124.h5
# working on file 2270: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_134.h5
# working on file 2280: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_144.h5
# working on file 2290: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_154.h5
# working on file 2300: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_164.h5
# working on file 2310: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_174.h5
# working on file 2320: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_184.h5
# working on file 2330: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_194.h5
# working on file 2340: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_204.h5
# working on file 2350: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_214.h5
# working on file 2360: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_224.h5
# working on file 2370: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_234.h5
# working on file 2380: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_244.h5
# working on file 2390: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_254.h5
# working on file 2400: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_264.h5
# working on file 2410: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_274.h5
# working on file 2420: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_284.h5
# working on file 2430: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_294.h5
# working on file 2440: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_304.h5
# working on file 2450: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_314.h5
# working on file 2460: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_324.h5
# working on file 2470: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_334.h5
# working on file 2480: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_344.h5
# working on file 2490: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_354.h5
# working on file 2500: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_364.h5
# working on file 2510: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_374.h5
# working on file 2520: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_384.h5
# working on file 2530: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_394.h5
# working on file 2540: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_404.h5
# working on file 2550: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_414.h5
# working on file 2560: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_424.h5
# working on file 2570: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_434.h5
# working on file 2580: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_444.h5
# working on file 2590: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_454.h5
# working on file 2600: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_464.h5
# working on file 2610: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_474.h5
# working on file 2620: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_484.h5
# working on file 2630: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_494.h5
# working on file 2640: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_504.h5
# working on file 2650: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_514.h5
# working on file 2660: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_524.h5
# working on file 2670: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_534.h5
# working on file 2680: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_544.h5
# working on file 2690: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_554.h5
# working on file 2700: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_564.h5
# working on file 2710: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_574.h5
# working on file 2720: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_584.h5
# working on file 2730: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_594.h5
# working on file 2740: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_604.h5
# working on file 2750: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_614.h5
# working on file 2760: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_624.h5
# working on file 2770: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_634.h5
# working on file 2780: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_644.h5
# working on file 2790: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_654.h5
# working on file 2800: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_664.h5
# working on file 2810: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_674.h5
# working on file 2820: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_684.h5
# working on file 2830: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_694.h5
# working on file 2840: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_704.h5
# working on file 2850: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_714.h5
# working on file 2860: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_724.h5

# %%
## time of calibration
cdat, attr, fhandle = bu.get_data(calib_file_dict['x'][250.0][0])
tcal = attr["Time"]

cdat, attr, fhandle = bu.get_data(noise_file_list[-1])
tcal_end = attr["Time"]

cdat, attr, fhandle = bu.get_data(data_list[0])
tstart = attr["Time"]

cal_start = (tcal-tstart)/3600
cal_end = (tcal_end-tstart)/3600
print(cal_start, cal_end)
# Out:
# 26.54917230354415 -465.14160325831836

# %%
## make a plot of the noise vs time
plt.figure(figsize=(8,6))

nstep = 40
n = int(np.sum(time_arr>-1)/nstep)+1
cmap = plt.get_cmap('jet')
colors = [cmap(i) for i in np.linspace(0, 1, n)]

integ_pts_lo = (freqs>10) & (freqs<20)
integ_pts_hi = (freqs>20) & (freqs<55)

cidx = 0
noise_vs_time = []
for i in range(np.shape(noise_arr)[0]):
    #if(time_arr[i] > 55): break
    if(i%nstep == 0):
        plt.semilogy(freqs, np.median(noise_arr[i:(i+nstep),:], axis=0), color=colors[cidx])
        cidx+=1


    integ_lo = np.trapz(noise_arr[i,integ_pts_lo], x=freqs[integ_pts_lo]) 
    integ_hi = np.trapz(noise_arr[i,integ_pts_hi], x=freqs[integ_pts_hi]) 

    noise_vs_time.append([time_arr[i], integ_lo, integ_hi])
        
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=time_arr[0], vmax=time_arr[-1]))
sm.set_array([])
ax = plt.gca()
plt.colorbar(sm, ax=ax, label="Time since start [hours]")

plt.semilogy(noise_dict['freq'], noise_dict['Jorig'], 'k-', label="Noise from calibration", lw=3)

plt.legend()
plt.xlim(0,100)
plt.xlabel("Frequency [Hz]")
plt.ylabel("PSD [V$^2$/Hz]")
plt.ylim(1e-8, 1e-2)

plt.savefig(plots_dir+"/noise_spec_vs_time_%s.png"%file_label, dpi=300)

noise_vs_time = np.array(noise_vs_time)

## compare file at 35 hours to one at 21 hours
bad_idx = np.argmin(np.abs(noise_vs_time[:,0]-4))
good_idx = np.argmin(np.abs(noise_vs_time[:,0]-52))

plt.figure(figsize=(14,8))
plt.subplot(2,1,1)
#plt.semilogy(noise_vs_time[:,0], noise_vs_time[:,1], 'b')
plt.semilogy(noise_vs_time[:,0], noise_vs_time[:,2], 'k')
plt.semilogy(noise_vs_time[bad_idx,0], noise_vs_time[bad_idx,2], 'ro')
plt.semilogy(noise_vs_time[good_idx,0], noise_vs_time[good_idx,2], 'bo')
plt.grid(True)
fill_dps(dead_period_edges)
fill_dps(lamp_period_edges, 'black', lab="UV lamp")
fill_dps(filament_period_edges, 'red', lab="Filament")
plt.xlim(time_hours[0], time_hours[-1])
plt.xlabel("Time since start [hours]")
plt.ylabel("Integral of noise PSD, 20-55 Hz [V$^2$]")
#plt.legend(loc="upper right")
yy = plt.ylim()
plt.plot([cal_start, cal_start], yy, 'k:', label="Calibration time")
plt.plot([cal_end, cal_end], yy, 'k--', label="Noise file time")
plt.legend(loc="lower left")

plt.subplot(2,1,2)
plt.plot(time_hours[1:], corr_vec[1:,corr_idx]/cal_fac, 'k-', label="Correlation")
plt.plot(time_hours[1:], running_charge, '-', color='orange', label="Recon. charge")
plt.grid(True)
fill_dps(dead_period_edges)
fill_dps(lamp_period_edges, 'black', lab="UV lamp")
fill_dps(filament_period_edges, 'red', lab="Filament")
plt.xlim(time_hours[0], time_hours[-1])
plt.xlabel("Time since start [hours]")
plt.ylabel("Net charge [$e$]")
#plt.legend(loc="upper right")

plt.savefig(plots_dir+"/noise_vs_time_%s.png"%file_label, dpi=300)

plt.show()

# %%
## compare an example "good" and "bad" file
bad_dat, attr, fhandle = bu.get_data(data_list[bad_idx])
good_dat, attr, fhandle = bu.get_data(data_list[good_idx])

tvec = np.arange(0, len(good_dat))/attr['Fsamp']

plt.figure(figsize=(14,12))

fc = np.array([20, 55])/(attr['Fsamp']/2)
b,a = sig.butter(3, fc, btype='bandpass')

coord = ['X', 'Y', 'Z']
for i in range(3):
    plt.subplot(3,1,i+1)

    bd = sig.filtfilt(b,a,bad_dat[:,i])
    gd = sig.filtfilt(b,a,good_dat[:,i])

    plt.plot(tvec, bd, 'r')
    plt.plot(tvec, gd, 'b')
    plt.xlim(tvec[0], tvec[-1])
    plt.xlabel("Time [s]")
    plt.ylabel(coord[i] + " voltage [V]")

plt.savefig(plots_dir+"/noise_bursts_%s.png"%file_label, dpi=300, bbox_inches="tight")

plt.show()

# %%
remake_files = True


if(remake_files):

    fc = np.array([20, 55])/(attr['Fsamp']/2)
    b,a = sig.butter(3, fc, btype='bandpass')

    files_to_use = data_list
    noise_rms = np.zeros(len(files_to_use))
    time_arr = np.zeros(len(files_to_use))
    for i,f in enumerate(files_to_use):

        if(i%10 == 0): print("working on file %d: %s"%(i, f))
        
        cdat, attr, fhandle = bu.get_data(f)
        if(not fhandle):
            continue    

        xdata = cdat[:,0]
        noise_rms[i] = np.median( np.sqrt( sig.filtfilt(b,a,xdata)**2 ) )
        time_arr[i] = attr["Time"]

    time_arr -= time_arr[0] # time since start
    time_arr /= 3600 ## convert to hours
    np.savez(os.path.join(data_dir, "noise_rms_vs_time.npz"), noise_rms=noise_rms, time_arr=time_arr)
else:
    npzfile = np.load(os.path.join(data_dir, "noise_rms_vs_time.npz"))
    noise_rms = npzfile['noise_rms']
    time_arr = npzfile['time_arr']
# Out:
# working on file 0: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_0.h5
# working on file 10: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_10.h5
# working on file 20: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_20.h5
# working on file 30: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_30.h5
# working on file 40: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_40.h5
# working on file 50: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_50.h5
# working on file 60: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_60.h5
# working on file 70: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_70.h5
# working on file 80: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_80.h5
# working on file 90: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_90.h5
# working on file 100: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_100.h5
# working on file 110: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_110.h5
# working on file 120: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_120.h5
# working on file 130: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_130.h5
# working on file 140: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_140.h5
# working on file 150: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_150.h5
# working on file 160: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_160.h5
# working on file 170: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_170.h5
# working on file 180: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_180.h5
# working on file 190: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_190.h5
# working on file 200: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_200.h5
# working on file 210: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_210.h5
# working on file 220: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_220.h5
# working on file 230: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_230.h5
# working on file 240: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_240.h5
# working on file 250: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_250.h5
# working on file 260: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_260.h5
# working on file 270: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_270.h5
# working on file 280: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_280.h5
# working on file 290: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_290.h5
# working on file 300: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_300.h5
# working on file 310: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_310.h5
# working on file 320: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_320.h5
# working on file 330: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_330.h5
# working on file 340: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_340.h5
# working on file 350: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_350.h5
# working on file 360: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_360.h5
# working on file 370: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_370.h5
# working on file 380: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_380.h5
# working on file 390: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_390.h5
# working on file 400: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_400.h5
# working on file 410: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_410.h5
# working on file 420: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_420.h5
# working on file 430: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_430.h5
# working on file 440: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_440.h5
# working on file 450: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_450.h5
# working on file 460: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_460.h5
# working on file 470: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_470.h5
# working on file 480: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_480.h5
# working on file 490: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_490.h5
# working on file 500: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_500.h5
# working on file 510: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_510.h5
# working on file 520: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_520.h5
# working on file 530: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_530.h5
# working on file 540: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_540.h5
# working on file 550: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_550.h5
# working on file 560: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_560.h5
# working on file 570: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_570.h5
# working on file 580: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_580.h5
# working on file 590: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_590.h5
# working on file 600: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_600.h5
# working on file 610: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_610.h5
# working on file 620: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_620.h5
# working on file 630: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_630.h5
# working on file 640: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_640.h5
# working on file 650: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_650.h5
# working on file 660: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_660.h5
# working on file 670: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_670.h5
# working on file 680: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_680.h5
# working on file 690: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_690.h5
# working on file 700: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_700.h5
# working on file 710: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_710.h5
# working on file 720: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_720.h5
# working on file 730: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_730.h5
# working on file 740: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_740.h5
# working on file 750: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_750.h5
# working on file 760: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_760.h5
# working on file 770: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_770.h5
# working on file 780: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_780.h5
# working on file 790: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_790.h5
# working on file 800: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_800.h5
# working on file 810: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_810.h5
# working on file 820: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_820.h5
# working on file 830: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_830.h5
# working on file 840: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_840.h5
# working on file 850: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_850.h5
# working on file 860: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_860.h5
# working on file 870: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_870.h5
# working on file 880: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_880.h5
# working on file 890: /Volumes/DATA/20231121/1/meas/1/LPmbar_xyzcool_890.h5
# working on file 900: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_8.h5
# working on file 910: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_18.h5
# working on file 920: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_28.h5
# working on file 930: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_38.h5
# working on file 940: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_48.h5
# working on file 950: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_58.h5
# working on file 960: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_68.h5
# working on file 970: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_78.h5
# working on file 980: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_88.h5
# working on file 990: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_98.h5
# working on file 1000: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_108.h5
# working on file 1010: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_118.h5
# working on file 1020: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_128.h5
# working on file 1030: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_138.h5
# working on file 1040: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_148.h5
# working on file 1050: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_158.h5
# working on file 1060: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_168.h5
# working on file 1070: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_178.h5
# working on file 1080: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_188.h5
# working on file 1090: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_198.h5
# working on file 1100: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_208.h5
# working on file 1110: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_218.h5
# working on file 1120: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_228.h5
# working on file 1130: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_238.h5
# working on file 1140: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_248.h5
# working on file 1150: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_258.h5
# working on file 1160: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_268.h5
# working on file 1170: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_278.h5
# working on file 1180: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_288.h5
# working on file 1190: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_298.h5
# working on file 1200: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_308.h5
# working on file 1210: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_318.h5
# working on file 1220: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_328.h5
# working on file 1230: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_338.h5
# working on file 1240: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_348.h5
# working on file 1250: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_358.h5
# working on file 1260: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_368.h5
# working on file 1270: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_378.h5
# working on file 1280: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_388.h5
# working on file 1290: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_398.h5
# working on file 1300: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_408.h5
# working on file 1310: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_418.h5
# working on file 1320: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_428.h5
# working on file 1330: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_438.h5
# working on file 1340: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_448.h5
# working on file 1350: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_458.h5
# working on file 1360: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_468.h5
# working on file 1370: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_478.h5
# working on file 1380: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_488.h5
# working on file 1390: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_498.h5
# working on file 1400: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_508.h5
# working on file 1410: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_518.h5
# working on file 1420: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_528.h5
# working on file 1430: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_538.h5
# working on file 1440: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_548.h5
# working on file 1450: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_558.h5
# working on file 1460: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_568.h5
# working on file 1470: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_578.h5
# working on file 1480: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_588.h5
# working on file 1490: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_598.h5
# working on file 1500: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_608.h5
# working on file 1510: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_618.h5
# working on file 1520: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_628.h5
# working on file 1530: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_638.h5
# working on file 1540: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_648.h5
# working on file 1550: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_658.h5
# working on file 1560: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_668.h5
# working on file 1570: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_678.h5
# working on file 1580: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_688.h5
# working on file 1590: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_698.h5
# working on file 1600: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_708.h5
# working on file 1610: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_718.h5
# working on file 1620: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_728.h5
# working on file 1630: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_738.h5
# working on file 1640: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_748.h5
# working on file 1650: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_758.h5
# working on file 1660: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_768.h5
# working on file 1670: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_778.h5
# working on file 1680: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_788.h5
# working on file 1690: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_798.h5
# working on file 1700: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_808.h5
# working on file 1710: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_818.h5
# working on file 1720: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_828.h5
# working on file 1730: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_838.h5
# working on file 1740: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_848.h5
# working on file 1750: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_858.h5
# working on file 1760: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_868.h5
# working on file 1770: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_878.h5
# working on file 1780: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_888.h5
# working on file 1790: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_898.h5
# working on file 1800: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_908.h5
# working on file 1810: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_918.h5
# working on file 1820: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_928.h5
# working on file 1830: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_938.h5
# working on file 1840: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_948.h5
# working on file 1850: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_958.h5
# working on file 1860: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_968.h5
# working on file 1870: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_978.h5
# working on file 1880: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_988.h5
# working on file 1890: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_998.h5
# working on file 1900: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1008.h5
# working on file 1910: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1018.h5
# working on file 1920: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1028.h5
# working on file 1930: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1038.h5
# working on file 1940: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1048.h5
# working on file 1950: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1058.h5
# working on file 1960: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1068.h5
# working on file 1970: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1078.h5
# working on file 1980: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1088.h5
# working on file 1990: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1098.h5
# working on file 2000: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1108.h5
# working on file 2010: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1118.h5
# working on file 2020: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1128.h5
# working on file 2030: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1138.h5
# working on file 2040: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1148.h5
# working on file 2050: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1158.h5
# working on file 2060: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1168.h5
# working on file 2070: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1178.h5
# working on file 2080: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1188.h5
# working on file 2090: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1198.h5
# working on file 2100: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1208.h5
# working on file 2110: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1218.h5
# working on file 2120: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1228.h5
# working on file 2130: /Volumes/DATA/20231121/1/meas/2/LPmbar_xyzcool_1238.h5
# working on file 2140: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_4.h5
# working on file 2150: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_14.h5
# working on file 2160: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_24.h5
# working on file 2170: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_34.h5
# working on file 2180: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_44.h5
# working on file 2190: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_54.h5
# working on file 2200: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_64.h5
# working on file 2210: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_74.h5
# working on file 2220: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_84.h5
# working on file 2230: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_94.h5
# working on file 2240: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_104.h5
# working on file 2250: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_114.h5
# working on file 2260: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_124.h5
# working on file 2270: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_134.h5
# working on file 2280: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_144.h5
# working on file 2290: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_154.h5
# working on file 2300: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_164.h5
# working on file 2310: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_174.h5
# working on file 2320: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_184.h5
# working on file 2330: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_194.h5
# working on file 2340: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_204.h5
# working on file 2350: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_214.h5
# working on file 2360: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_224.h5
# working on file 2370: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_234.h5
# working on file 2380: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_244.h5
# working on file 2390: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_254.h5
# working on file 2400: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_264.h5
# working on file 2410: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_274.h5
# working on file 2420: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_284.h5
# working on file 2430: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_294.h5
# working on file 2440: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_304.h5
# working on file 2450: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_314.h5
# working on file 2460: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_324.h5
# working on file 2470: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_334.h5
# working on file 2480: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_344.h5
# working on file 2490: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_354.h5
# working on file 2500: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_364.h5
# working on file 2510: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_374.h5
# working on file 2520: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_384.h5
# working on file 2530: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_394.h5
# working on file 2540: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_404.h5
# working on file 2550: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_414.h5
# working on file 2560: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_424.h5
# working on file 2570: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_434.h5
# working on file 2580: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_444.h5
# working on file 2590: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_454.h5
# working on file 2600: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_464.h5
# working on file 2610: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_474.h5
# working on file 2620: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_484.h5
# working on file 2630: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_494.h5
# working on file 2640: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_504.h5
# working on file 2650: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_514.h5
# working on file 2660: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_524.h5
# working on file 2670: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_534.h5
# working on file 2680: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_544.h5
# working on file 2690: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_554.h5
# working on file 2700: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_564.h5
# working on file 2710: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_574.h5
# working on file 2720: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_584.h5
# working on file 2730: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_594.h5
# working on file 2740: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_604.h5
# working on file 2750: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_614.h5
# working on file 2760: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_624.h5
# working on file 2770: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_634.h5
# working on file 2780: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_644.h5
# working on file 2790: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_654.h5
# working on file 2800: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_664.h5
# working on file 2810: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_674.h5
# working on file 2820: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_684.h5
# working on file 2830: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_694.h5
# working on file 2840: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_704.h5
# working on file 2850: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_714.h5
# working on file 2860: /Volumes/DATA/20231121/1/meas/3/LPmbar_xyzcool_724.h5

# %%
plt.figure(figsize=(14,5))

plt.semilogy(noise_vs_time[:,0], noise_vs_time[:,2], 'k', label="PSD integral")
plt.semilogy(time_arr, noise_rms/1e2, 'r', label="RMS cutting bursts")
plt.legend()
fill_dps(dead_period_edges)
fill_dps(lamp_period_edges, 'black', lab="UV lamp")
fill_dps(filament_period_edges, 'red', lab="Filament")
plt.xlim(0,time_hours[-1])
plt.xlabel("Time since start [hours]")
plt.ylabel("Noise PSD/RMS [V$^2$]")

plt.savefig(plots_dir+"/noise_rms_vs_time_%s.png"%file_label, dpi=300, bbox_inches="tight")

plt.ylim(1e-5, 1e-3)
plt.grid(True, which='both')

plt.savefig(plots_dir+"/noise_rms_zoom_%s.png"%file_label, dpi=300, bbox_inches="tight")

plt.show()

# %%
#idx_of_charge_changes = np.where(changes)[0]
#good_changes = np.diff(idx_of_charge_changes) > 0
#good_changes = np.hstack((good_changes,[True])) ## add the last one
#idx_of_charge_changes = idx_of_charge_changes[good_changes]

idx_of_charge_changes = []
change_times = good_change_list[:,0]
for ct in change_times:
    idx_of_charge_changes.append(np.argmin(np.abs(time_hours[1:]-ct)))

file_idx_of_charge_changes = (np.array(idx_of_charge_changes)+1)/num_pts_per_file
#for i in file_idx_of_charge_changes:
#    print("%d, 0"%i)

# %%
calibrated_OF_amps_from_fit
# Out:
# array([4.72659924e-05, 4.35548938e-05, 1.99571583e-04])

# %%
## charge calibration factors
recal_fac = 170.5/np.median(corr_vec[:,3]) * np.sqrt(2.8) ## relative to 30 mV, 111 Hz
cal_fac_fine, cal_fac_coarse = 6126.7*recal_fac**2, 47.57*recal_fac**2 ## factor of 4 for (30 mV/15 mV)^2

## roll to the average difference in max times
filt_bins_offset = int(fit_vals_offset[0][1]-fit_vals_offset[1][1])

# %%
## now assemble a list of the candidate decays and use the recon methods above to look for pulses
remake_files = False


importlib.reload(bu)

idx_to_use = [0,1,2]
step_times = np.loadtxt(os.path.join(data_dir, "step_times_%s.txt"%file_label), delimiter=',')
xwind = 5
cwind = 0.5

step_subtract = False
do_subtract_plots = False

plot_prepulse = False

save_png = [] #2, 32, 41]

max_files_per_pdf = 100
pdf_idx = 0

if(step_subtract):  
    fname = data_dir+"/pulse_plot_step_sub_%s.pkl"%file_label
else:
    fname = data_dir+"/pulse_plot_%s.pkl"%file_label

if(remake_files):

    pulse_data = {}
    fig = plt.figure(figsize=(12,6))
    for j,idx in enumerate(np.unique(np.floor(file_idx_of_charge_changes))):

        if(j % max_files_per_pdf == 0):
            pdf = PdfPages(os.path.join(plots_dir, "candidate_decays_%s_%d.pdf"%(file_label, pdf_idx)))
            pdf_is_open = True

            if(step_subtract and do_subtract_plots):
                pdf_sub = PdfPages(os.path.join(plots_dir, "candidate_decays_step_sub_%s_%d.pdf"%(file_label, pdf_idx)))
                fig_sub = plt.figure(figsize=(12,8))
            else:
                fig_sub = []

            if(plot_prepulse):
                pdf_prepulse = PdfPages(os.path.join(plots_dir, "prepulse_%s_%d.pdf"%(file_label, pdf_idx)))  
                fig_prepulse = plt.figure(figsize=(12,8))              

        print("working on file: ", int(idx))
        #if(j>7): break
        #if(idx != 1111): continue
        step_idx = np.floor(step_times[:,0]).astype(int).tolist().index(int(idx))
        step_time = step_times[step_idx,1]
        #if(step_time == 0): step_time = 50
        if(step_time < 0): continue

        cfile = data_list[int(idx)]
        cdat, attr, _ = bu.get_data(cfile)
        yup = 75 #if idx > 500 else 800
        omega0, gamma = 2*np.pi*37.8, 2*np.pi*4.2

        if(step_time > 0):
            xrange=[step_time-xwind,step_time+xwind]
            charge_range=[step_time-cwind,step_time+cwind]
        else:
            xrange, charge_range = [-1, -1], [-1, -1]

        curr_step_params = bu.plot_impulse_with_recon_3D(cdat, attr, template_dict_fit, noise_dict_3D, cal_facs=[cal_fac_fine, cal_fac_coarse], 
                                                    amp_cal_facs=[volts_per_meters, calibrated_OF_amps_from_fit], ylim_init=[0,200],
                                                    filt_time_offset = filt_bins_offset, drive_idx=8, figout=fig, do_lowpass=True, 
                                                    xrange=xrange, charge_range=charge_range, rasterized=True, res_pars=[omega0, gamma],
                                                    filt_charge_data=True, field_cal_fac=0.8, ylim2_scale=4.75, plot_wind_zoom=1,
                                                    ylim_nm=[-20,50], ylim_nm_z=[-20,50], charge_wind=10, plot_peak=True,
                                                    subtract_sine_step=step_subtract, do_subtract_plots=do_subtract_plots, figsub=fig_sub,
                                                    fit_prepulse=True, prepulse_fig=fig_prepulse, drive_freq=151)
        
        #opt_filt_amps_1D = bu.optimal_filt_1D(calib_file_dict, template_dict_fit, noise_dict_3D, time_offset=8, 
        #           drive_idx=10, cal_fac=4.2e-8, make_plots=False, coord='x') 

        plt.figure(fig.number)
        file_parts = '/'.join(cfile.split("/")[-2:])
        ctime = (attr['Time']-corr_vec[0,-1])/3600
        plt.suptitle("Candidate decay %d, time=%.1f hrs, file idx=%d, name=%s"%(j, ctime, int(idx), file_parts))
        curr_step_params['time_hours'] = ctime
        pulse_data[idx] = curr_step_params

        if(idx in save_png):
            plt.savefig(plots_dir+"/candidate_decay_%s_%d.png"%(file_label, idx), dpi=150, bbox_inches="tight")

        try:
            pdf.savefig(dpi=150, bbox_inches="tight")
        except TimeoutError:
            print("Timeout error, trying again")
            pdf.savefig(dpi=150, bbox_inches="tight")
        fig.clf()

        if(step_subtract and do_subtract_plots):
            plt.figure(fig_sub.number)
            plt.suptitle("Candidate decay %d, time=%.1f hrs, file idx=%d, name=%s"%(j, ctime, int(idx), file_parts))
            pdf_sub.savefig(dpi=150, bbox_inches="tight")
            fig_sub.clf()

        if(plot_prepulse):
            plt.figure(fig_prepulse.number)
            plt.suptitle("Candidate decay %d, time=%.1f hrs, file idx=%d, name=%s"%(j, ctime, int(idx), file_parts))
            pdf_prepulse.savefig(dpi=150, bbox_inches="tight")
            fig_prepulse.clf()

        if((j+1) % max_files_per_pdf == 0):
            pdf.close()
            pdf_is_open = False
            pdf_idx += 1
    
    if(pdf_is_open):
        pdf.close()
        if(step_subtract and do_subtract_plots):
            pdf_sub.close()
        if(plot_prepulse):
            pdf_prepulse.close()

    with open(fname, 'wb') as fout:
        pickle.dump(pulse_data, fout)
else:
    
    with open(fname, 'rb') as fin:
        pulse_data = pickle.load(fin)

plt.close(fig)
if(fig_sub):
    plt.close(fig_sub)
if(fig_prepulse):
    plt.close(fig_prepulse)
# Out:
# working on file:  8
# working on file:  13
# working on file:  20
# working on file:  38
# working on file:  42
# working on file:  44
# working on file:  45
# working on file:  53
# working on file:  61
# working on file:  64
# working on file:  71
# working on file:  91
# working on file:  93
# working on file:  107
# working on file:  108
# working on file:  124
# working on file:  140
# working on file:  151
# working on file:  157
# working on file:  192
# working on file:  237
# working on file:  268
# working on file:  273
# working on file:  276
# working on file:  309
# working on file:  312
# working on file:  355
# working on file:  363
# working on file:  384
# working on file:  393
# working on file:  461
# working on file:  485
# working on file:  545
# working on file:  666
# working on file:  704
# working on file:  706
# working on file:  957
# working on file:  993
# working on file:  1111
# working on file:  1139
# working on file:  1387
# working on file:  1402
# working on file:  1655
# working on file:  1711
# working on file:  2511

# %%
remake_files = False
importlib.reload(bu)

if(remake_files):
    pdf = PdfPages(os.path.join(plots_dir, "candidate_alpha_det_%s.pdf"%file_label))

    for j,idx in enumerate(np.unique(np.floor(file_idx_of_charge_changes))):
        print("working on file: ", int(idx))
        #if(j>2): break
        step_idx = np.floor(step_times[:,0]).astype(int).tolist().index(int(idx))
        step_time = step_times[step_idx,1]
        if(step_time <= 0): step_time = 50

        cfile = data_list[int(idx)]
        cdat, attr, _ = bu.get_data(cfile)

        fig = bu.plot_step_with_alphas(cdat, attr, xrange=[step_time-xwind,step_time+xwind], cal_facs=[cal_fac_fine, cal_fac_coarse], 
                                    charge_range=[step_time-cwind,step_time+cwind], drive_freq=151)

        file_parts = '/'.join(cfile.split("/")[-2:])
        ctime = (attr['Time']-corr_vec[0,-1])/3600
        plt.suptitle("Candidate decay %d, time=%.1f hrs, file idx=%d, name=%s"%(j, ctime, int(idx), file_parts))
        try:
            pdf.savefig(dpi=75)
        except TimeoutError:
            print("Timeout error, trying again")
            pdf.savefig(dpi=75)
        plt.close(fig)

    pdf.close()
# Out:
# working on file:  8
# working on file:  13
# working on file:  20
# working on file:  38
# working on file:  42
# working on file:  44
# working on file:  45
# working on file:  53
# working on file:  61
# working on file:  64
# working on file:  71
# working on file:  91
# working on file:  93
# working on file:  107
# working on file:  108
# working on file:  124
# working on file:  140
# working on file:  151
# working on file:  157
# working on file:  192
# working on file:  237
# working on file:  268
# working on file:  273
# working on file:  276
# working on file:  309
# working on file:  312
# working on file:  355
# working on file:  363
# working on file:  384
# working on file:  393
# working on file:  461
# working on file:  485
# working on file:  545
# working on file:  666
# working on file:  704
# working on file:  706
# working on file:  957
# working on file:  993
# working on file:  1111
# working on file:  1139
# working on file:  1387
# working on file:  1402
# working on file:  1655
# working on file:  1711
# working on file:  2511

# %%
for file_idx in [0,1,2]:
    amp = 250

    fname = calib_file_dict['x'][amp][file_idx]
    cdat, attr, _ = bu.get_data(fname)

    b,a = sig.butter(3, [20/(attr['Fsamp']/2), 115/(attr['Fsamp']/2)], btype='bandpass')
    xfilt = sig.filtfilt(b,a,cdat[:,0])

    blp, alp = sig.butter(3, 10/(attr['Fsamp']/2), btype='lowpass')
    xfilt2 = np.sqrt(sig.filtfilt(blp,alp,xfilt**2)*2)

    bslp, aslp = sig.butter(3, 20/(attr['Fsamp']/2), btype='lowpass')

    xpos_dc = sig.filtfilt(bslp,aslp,cdat[:,0])
    ypos_dc = sig.filtfilt(bslp,aslp,cdat[:,1])
    zpos_dc = sig.filtfilt(bslp,aslp,cdat[:,2])

    xlims = [0, len(zpos_dc)] #[6e5, 7e5]

    plt.figure(figsize=(20,10))
    plt.subplot(4,1,1)
    plt.plot(xfilt)
    plt.plot(xfilt2)
    #plt.plot(zpos_dc*0.5)
    plt.plot(cdat[:,10]*0.1,'r', zorder=0)
    plt.xlim(xlims)
    plt.gca().set_xticklabels([])
    #plt.xlim(8e5, 9e5)
    plt.ylabel("X Voltage [V]")
    plt.title(fname)
    plt.ylim(-0.05, 0.05)

    plt.subplot(4,1,2)
    plt.plot(xpos_dc)
    plt.xlim(xlims)
    plt.gca().set_xticklabels([])
    plt.ylabel("X Voltage [V]")

    plt.subplot(4,1,3)
    plt.plot(ypos_dc)
    plt.xlim(xlims)
    plt.gca().set_xticklabels([])
    plt.ylabel("Y Voltage [V]")

    plt.subplot(4,1,4)
    plt.plot(zpos_dc)
    plt.ylabel("Z position [V]")
    plt.xlim(xlims)
    plt.xlabel("Samples [ADC time units]")

    plt.subplots_adjust(hspace=0)

    plt.savefig(plots_dir+"/calib_example_%s_%d.png"%(file_label, file_idx), dpi=300, bbox_inches="tight")

plt.show()
# Out:
# /var/folders/sz/h29lm_2j53v8vmw0zm_6hxqm0000gn/T/ipykernel_2452/409302321.py:11: RuntimeWarning: invalid value encountered in sqrt
#   xfilt2 = np.sqrt(sig.filtfilt(blp,alp,xfilt**2)*2)

# %%
plt.figure(figsize=(20,2.5))
plt.plot(xfilt)
plt.plot(xfilt2)
#plt.plot(zpos_dc*0.5)
plt.plot(cdat[:,10]*0.1,'r', zorder=0)
plt.xlim(xlims)
#plt.gca().set_xticklabels([])
#plt.xlim(8e5, 9e5)
plt.ylabel("Y Voltage [V]")
plt.title(fname)
plt.ylim(-0.05, 0.05)
plt.xlim(0,0.1e6)
plt.xlabel("Samples [ADC time units]")
plt.savefig(plots_dir+"/calib_example_%s_%d_xzoom.png"%(file_label, file_idx), dpi=300, bbox_inches="tight")

# %%
for file_idx in [0,1,2]:
    amp = 250

    fname = calib_file_dict['y'][amp][file_idx]
    cdat, attr, _ = bu.get_data(fname)

    b,a = sig.butter(3, [20/(attr['Fsamp']/2), 115/(attr['Fsamp']/2)], btype='bandpass')
    yfilt = sig.filtfilt(b,a,cdat[:,1])

    blp, alp = sig.butter(3, 10/(attr['Fsamp']/2), btype='lowpass')
    yfilt2 = np.sqrt(sig.filtfilt(blp,alp,yfilt**2)*2)

    bslp, aslp = sig.butter(3, 20/(attr['Fsamp']/2), btype='lowpass')

    xpos_dc = sig.filtfilt(bslp,aslp,cdat[:,0])
    ypos_dc = sig.filtfilt(bslp,aslp,cdat[:,1])
    zpos_dc = sig.filtfilt(bslp,aslp,cdat[:,2])

    xlims = [0, len(zpos_dc)] #[6e5, 7e5]

    plt.figure(figsize=(20,10))
    plt.subplot(4,1,1)
    plt.plot(yfilt)
    plt.plot(yfilt2)
    #plt.plot(zpos_dc*0.5)
    plt.plot(cdat[:,10]*0.1,'r', zorder=0)
    plt.xlim(xlims)
    plt.gca().set_xticklabels([])
    #plt.xlim(8e5, 9e5)
    plt.ylabel("Y Voltage [V]")
    plt.title(fname)
    plt.ylim(-0.05, 0.05)

    plt.subplot(4,1,2)
    plt.plot(xpos_dc)
    plt.xlim(xlims)
    plt.gca().set_xticklabels([])
    plt.ylabel("X Voltage [V]")

    plt.subplot(4,1,3)
    plt.plot(ypos_dc)
    plt.xlim(xlims)
    plt.gca().set_xticklabels([])
    plt.ylabel("Y Voltage [V]")

    plt.subplot(4,1,4)
    plt.plot(zpos_dc)
    plt.ylabel("Z position [V]")
    plt.xlim(xlims)
    plt.xlabel("Samples [ADC time units]")

    plt.subplots_adjust(hspace=0)

    plt.savefig(plots_dir+"/calib_example_y_%s_%d.png"%(file_label, file_idx), dpi=300, bbox_inches="tight")

plt.show()
# Out:
# /var/folders/sz/h29lm_2j53v8vmw0zm_6hxqm0000gn/T/ipykernel_2452/2328938433.py:11: RuntimeWarning: invalid value encountered in sqrt
#   yfilt2 = np.sqrt(sig.filtfilt(blp,alp,yfilt**2)*2)

# %%
plt.figure(figsize=(20,2.5))
plt.plot(yfilt)
plt.plot(yfilt2)
#plt.plot(zpos_dc*0.5)
plt.plot(cdat[:,10]*0.1,'r', zorder=0)
plt.xlim(xlims)
#plt.gca().set_xticklabels([])
#plt.xlim(8e5, 9e5)
plt.ylabel("Y Voltage [V]")
plt.title(fname)
plt.ylim(-0.05, 0.05)
plt.xlim(0,0.1e6)
plt.xlabel("Samples [ADC time units]")
plt.savefig(plots_dir+"/calib_example_%s_%d_yzoom.png"%(file_label, file_idx), dpi=300, bbox_inches="tight")
